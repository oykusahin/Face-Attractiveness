# %%
# %tensorflow_version 1.15
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.15`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import logging
import os
from PIL import Image
import numpy as np
import random
import time
import json
import math

# %%
#walks through the cfg file to get the information about the architecture and hyperparameters
def parsecfg(filedir):
    file = open(filedir, 'r')
    lines = file.read().split('\n')                        
    lines = [x for x in lines if len(x) > 0]               
    lines = [x for x in lines if x[0] != '#']              
    lines = [x.rstrip().lstrip() for x in lines]           

    block = {}
    blocks = []

    for line in lines:
      if line[0] == "[":               
        if len(block) != 0:         
          blocks.append(block)     
          block = {}               
        block["type"] = line[1:-1].rstrip()    
      else:
        key,value = line.split("=")
        block[key.rstrip()] = value.lstrip()
    blocks.append(block)
    return blocks

# %%
blocks=parsecfg("/content/gdrive/My Drive/CS559/HWNet_6_v14.cfg")
#creates the hyperparameters dictionary
hyperparameters = {}
for key in blocks[0]:
  val = blocks[0][key]
  hyperparameters[key]=val
print(hyperparameters)
# Out:
# {'type': 'net', 'img_size': '80', 'train_color': 'rgb', 'batch_normalization': '1', 'dropout': '1', 'beta1': '0.009', 'beta': '0.0001', 'beta2': '0.9991', 'epsilon': '1e-08', 'learning_rate': '0.0001', 'batch_size': '128', 'epoch': '500', 'early': '0', 'loss': 'mae', 'init': 'xavier'}

# %%
def data_loader(file_dir, num_data, size, channel_type):
    print("Started loading data")
    images = []
    labels = []
    count  = 0
    
    all_files = os.listdir(file_dir)
    #since the dataset has given us in a sorted order we need to shuffle the dataset
    #instead of using some fancy method we just go straightforward and randomly get the images
    r = list(range(num_data))
    random.shuffle(r)
    for i in r:
        if channel_type =="greyscale":
          channel= 1
          im = Image.open(file_dir+all_files[i],"r").convert('L') #getting the image, converting it to the greyscale
        else:
          channel=3
          im = Image.open(file_dir + all_files[i],"r")            #getting the image
        label = all_files[i].split(".jpg")[0].split("_")[0]       #getting the label from name
        temp_data = np.asarray(im.getdata())                      #converting the image -> pixels
        pix_val = np.resize(temp_data,(size, size, channel))      #the data already in expected size but just in case
        pix_val = np.true_divide(pix_val, 255)                    #normalization of pixels
        images = np.append(images, pix_val)                       #putting all pixels to one array, will be reshaped later
        labels = np.append(labels, label)                         #putting all labels to one array, will be reshaped later 
        count = count + 1                                         #counting the number of samples

    images = np.reshape(images, (count, size,size,channel))       #pixels reshaped
    images = images.astype('float32')
    labels = np.reshape(labels, (count, 1))                       #labels reshaped
    labels = labels.astype('float32')

    print("shape for images: " + str(images.shape))               #just to make sure everything is retrieved as we wanted
    print("shape for labels: " + str(labels.shape))             

    return images, labels

# %%
print("Getting the training data")
#If the greyscale selected the number of channels will be equal to 1
#if RGB selected, the number of channels will be equal to 3
#These values also passed to the dataLoader method to retrieve data accordingly
if hyperparameters['train_color']=='greyscale':
  num_channels= 1
elif hyperparameters['train_color']=='rgb':
  num_channels = 3

#According to the file directory the images are retrieved and set to the values.
file_dir_train = "/content/gdrive/My Drive/CS559/SCUT_FBP5500_downsampled/training/"
images, labels = data_loader(file_dir_train,3550, int(hyperparameters['img_size']) , hyperparameters['train_color']) #3550
print(hyperparameters['train_color'])

print("Getting the validation data")
file_dir_val = "/content/gdrive/My Drive/CS559/SCUT_FBP5500_downsampled/test/"
images_val, labels_val = data_loader(file_dir_val, 892, int(hyperparameters['img_size']), hyperparameters['train_color']) #892

print("Getting the testing data")
file_dir_test = "/content/gdrive/My Drive/CS559/SCUT_FBP5500_downsampled/validation/"
images_test, labels_test = data_loader(file_dir_test, 893, int(hyperparameters['img_size']), hyperparameters['train_color']) #893
# Out:
# Getting the training data
# Started loading data
# shape for images: (3550, 80, 80, 3)
# shape for labels: (3550, 1)
# rgb
# Getting the validation data
# Started loading data
# shape for images: (892, 80, 80, 3)
# shape for labels: (892, 1)
# Getting the testing data
# Started loading data
# shape for images: (893, 80, 80, 3)
# shape for labels: (893, 1)

# %%
#Creating the conv layer for the network
#if the net part of the config file has 1 for batch normalization we activate the batch normalization here
def conv2D(x, W, b, stride = 1, pad = 'SAME'):
    x = tf.nn.conv2d(x, W, stride, pad)
    x = tf.nn.bias_add(x, b)
    #If you want to measure the effect of the batch normalization change it to 0 from configuration file
    if hyperparameters['batch_normalization'] == 1:
      mean, var = tf.nn.moments(x, [0,1,2], name='moments')
      x = tf.nn.batch_normalization(x, mean, var, variance_epsilon = 1e-3, name=None)
    #ReLU activation function was selected as the major activation
    x = tf.nn.relu(x)
    return  x

#Method for the max pooling
#If stride is 1 then the shape of X wont change
#If stride is 2 then the shape of X will reduced
#Since we use placeholders while implementing the code the parameters that will initialize before the forward pass will not 
#effect from the change in size. 
def maxpool2d(x, k):
    #change its value to 1 from config file in order to observe the effect of it. 
    if hyperparameters['dropout'] == 1:
      x = tf.nn.dropout( x, 0.5)
    ksize = [1,k,k,1]
    strides= [1,k,k,1]
    return tf.nn.max_pool2d(x, ksize, strides,padding='SAME')

#we need placeholders to pass data in when the session will be run.
#Just a default method we needed because we are using Tensorflow version 1.15
#Things change in the new versions of TF
def create_placeholders(n_s, n_xc, n_y):
    X = tf.placeholder(tf.float32, [None, n_s, n_s, n_xc], name="X")
    Y = tf.placeholder(tf.float32, [None, n_y], name="Y")    
    return X, Y

#In order to observe the effect of different loss functions change the values of loss from the config file 
def getLoss(loss, Y, pred):
    #Loss for Mean Squared Error
    if loss == "mse":
        return tf.compat.v1.losses.mean_squared_error(labels=Y, predictions=pred)
    #Loss for Mean Average Error
    elif loss == "mae":
        return tf.reduce_mean(tf.abs(tf.subtract(Y, pred)))
    #Loss for Log-cosh Error
    elif loss == "logcosh":
        return tf.math.reduce_sum(tf.math.log(tf.cosh(pred - Y)))

# %%
#Method to initialize the parameters which will be get ready for the forward pass
def initialize_parameters(blocks):
  parameters_w = {}                          #the placeholder parameters for weights will be stored as dictionary
  parameters_b = {}                          #the placeholder parameters for biases will be stored as dictionary
  stride_counter=0                           #in order to decide the input shape for the first fully connected layer
  num_filter = []                            #since as input the previous layers size used we had to store all the size of the values
  img_size = hyperparameters['img_size']     #the size of the image from config file
  init= hyperparameters['init']              #the initializer type from config file
  initializer =None                          #the value of it will be given in teh following if-else bllock
  fc_flag=False                              #flag to trace the first fully connected layer
  #If-else block to decide initialization method
  #If you want to observe the effect of initialization on the results change values from config file.
  if init =='xavier':
    print(init + " initialized")
    initializer= tf.contrib.layers.xavier_initializer()
  elif init == 'gauss':
    print(init + " initialized")
    initializer = tf.compat.v1.random_uniform_initializer()

  with tf.compat.v1.variable_scope("init",reuse=tf.compat.v1.AUTO_REUSE): #TFv15 requirement
    #walks through each block value to initialize parameters
    for i in range(len(blocks)):
      module_type = blocks[i]['type']                   #gets the type of the layer
      if i ==0:
        num_filter=np.append(num_filter, 0)             #since the first part of the config file consist of the values of hyperparameters
      else:
        w_name = 'w'+str(i)                             #created names of the weights for the dictionary
        b_name = 'b'+str(i)                             #created names of the biases  for the dictionary
        stride = int(blocks[i]['stride'])               #gets the valur of stride
        if stride ==2:                                  #counts the number of stride =2 because we need these to create the first FC layer
          stride_counter=stride_counter+1           
        kernel = int(blocks[i]['kernel'])               #gets the value of the size of the kernel
        num_filters = int(blocks[i]['filter'])          #gets the value of the size of the filters
        num_filter = np.append(num_filter, num_filters) #pushes value of the size of the filters to the array
        #If the layer type is convolutional the parameters for the conv layers created
        if module_type == 'conv':                       
          #Since the first convolutional layer takes the image tensor as input we need to distinguish the first layer from others
          if i ==1:
            parameters_w[i] = tf.compat.v1.get_variable(w_name, shape = [kernel, kernel, num_channels, num_filters]   , initializer=initializer)
            parameters_b[i] = tf.compat.v1.get_variable(b_name ,shape = (num_filters) , initializer = initializer)
          else:
            parameters_w[i] = tf.compat.v1.get_variable(w_name, shape = [kernel, kernel, num_filter[i-1], num_filters]   , initializer = initializer)
            parameters_b[i] = tf.compat.v1.get_variable(b_name ,shape = (num_filters) , initializer = initializer)
        #If the layer type is fully connected, the parameters for the densed layers are created
        elif module_type == 'fully':
          if fc_flag is False:
            dense =int(img_size)  
            for j in range(stride_counter):
              dense = dense / 2
              dense = int(math.ceil(dense))
              print(dense)
            parameters_w[i] = tf.compat.v1.get_variable(w_name , shape = [(dense*dense*num_filters), num_filters], initializer = initializer)
            parameters_b[i] = tf.compat.v1.get_variable(b_name, shape = (num_filters), initializer = initializer)
            fc_flag=True
          else:
            parameters_w[i] = tf.compat.v1.get_variable(w_name , shape = [num_filter[i-1], num_filters], initializer = initializer)
            parameters_b[i] = tf.compat.v1.get_variable(b_name, shape = (num_filters), initializer = initializer)
        #If the layer type is regression, the parameters for the last layers are created
        elif module_type == 'regression':
          parameters_w[i] = tf.compat.v1.get_variable(w_name , shape = [num_filter[i-1], 1] , initializer = initializer)
          parameters_b[i] = tf.compat.v1.get_variable(b_name , shape = (1), initializer = initializer)
    return parameters_w, parameters_b
# Out:
# xavier initialized
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# 40
# 20
# 10
# {1: <tf.Variable 'init/w1:0' shape=(3, 3, 3, 32) dtype=float32_ref>,
#  2: <tf.Variable 'init/w2:0' shape=(3, 3, 32, 32) dtype=float32_ref>,
#  3: <tf.Variable 'init/w3:0' shape=(3, 3, 32, 32) dtype=float32_ref>,
#  4: <tf.Variable 'init/w4:0' shape=(3, 3, 32, 64) dtype=float32_ref>,
#  5: <tf.Variable 'init/w5:0' shape=(3, 3, 64, 64) dtype=float32_ref>,
#  6: <tf.Variable 'init/w6:0' shape=(3, 3, 64, 64) dtype=float32_ref>,
#  7: <tf.Variable 'init/w7:0' shape=(3, 3, 64, 64) dtype=float32_ref>,
#  8: <tf.Variable 'init/w8:0' shape=(3, 3, 64, 128) dtype=float32_ref>,
#  9: <tf.Variable 'init/w9:0' shape=(3, 3, 128, 128) dtype=float32_ref>,
#  10: <tf.Variable 'init/w10:0' shape=(3, 3, 128, 128) dtype=float32_ref>,
#  11: <tf.Variable 'init/w11:0' shape=(12800, 128) dtype=float32_ref>,
#  12: <tf.Variable 'init/w12:0' shape=(128, 128) dtype=float32_ref>,
#  13: <tf.Variable 'init/w13:0' shape=(128, 64) dtype=float32_ref>,
#  14: <tf.Variable 'init/w14:0' shape=(64, 64) dtype=float32_ref>,
#  15: <tf.Variable 'init/w15:0' shape=(64, 32) dtype=float32_ref>,
#  16: <tf.Variable 'init/w16:0' shape=(32, 32) dtype=float32_ref>,
#  17: <tf.Variable 'init/w17:0' shape=(32, 16) dtype=float32_ref>,
#  18: <tf.Variable 'init/w18:0' shape=(16, 1) dtype=float32_ref>}

# %%
#Forward propogation 
#X : tensor for input images
#p_w: dictionary which stores the weights(initialized, with placeholders)
#p_b: dictionary which stores the biases (initialized, with placeholders)
def forward_propagation(X, p_w, p_b):    
    layers = {}
    fc_flag=False                                               #in forward propogation we needed flag for FC as well, because we only need to reshape the layer once
    for i, module in enumerate(blocks):                         #walks through the blocks
      module_type = (module['type'])
      if module_type == 'conv':
        stride = int(blocks[i]['stride'])
        layer_name = str(i)
        if bool(layers) == False:
          layers[layer_name] = conv2D(X, p_w[i] , p_b[i])         #pass the value of input tensor
          layers[layer_name] = maxpool2d(layers[str(i)], k=stride)#maxs pools the convolutional layer
          print(str(layers[layer_name].shape))                    #prints the shape of the layer to double check the architecture
        else:
          layers[layer_name] = conv2D(layers[str(i-1)], p_w[i] , p_b[i])
          layers[layer_name] = maxpool2d(layers[str(i)], k=stride)
          print(str(layers[layer_name].shape))
      elif module_type == 'fully':
        if fc_flag is False:
          layer_name=str(i)
          layers[layer_name] = tf.reshape(layers[str(i-1)], [-1, parameters_w[i].get_shape().as_list()[0]]) #reshapes the result of the previous convolutional layer
          layers[layer_name] = tf.add(tf.matmul(layers[layer_name], parameters_w[i]), parameters_b[i])
          if hyperparameters['batch_normalization'] == 1:
              mean, var = tf.nn.moments(layers[layer_name], [0], name='moments')
              layers[layer_name] = tf.nn.batch_normalization(layers[layer_name], mean, var, variance_epsilon = 1e-3, name=None) #applies batch normalization to FC as well
          layers[layer_name] = tf.nn.relu(layers[str(i)])
          if hyperparameters['dropout'] == 1:
            layers[layer_name] = tf.nn.dropout(layers[layer_name], 0.5)
          print(layers[layer_name].shape)
        else:
          layers[layer_name] = tf.add(tf.matmul(layers[str(i-1)], parameters_w[i]), parameters_b[i])
          if hyperparameters['batch_normalization'] == 1:
            mean, var = tf.nn.moments(layers[layer_name], [0], name='moments')
            layers[layer_name] = tf.nn.batch_normalization(layers[layer_name], mean, var, variance_epsilon = 1e-3, name=None)
          layers[layer_name] = tf.nn.relu(layers[str(i)])
          if hyperparameters['dropout'] == 1:
            layers[layer_name] = tf.nn.dropout(layers[layer_name], 0.5)             #applies dropout for the fully connected layer
          print(layers[layer_name].shape)
          print(deneme)
      elif module_type == 'regression':
        reg_layer = tf.add(tf.matmul(layers[str(i-1)], p_w[i]), p_b[i])
        print(reg_layer.shape)
        return reg_layer
  
    return "Error: There is no regression layer. Add regression layer to the cfg file"

# %%
X = tf.placeholder("float")
Y = tf.placeholder("float")

n_samples = images.shape[0]
parameters_w, parameters_b = initialize_parameters(blocks)
pred = forward_propagation(X, parameters_w, parameters_b)
loss = getLoss(hyperparameters['loss'], Y, pred)
regularizers = 0
for i in range(len(parameters_w)):
  regularizers = regularizers + tf.nn.l2_loss(parameters_w[i+1])
loss = loss + float(hyperparameters['beta']) * regularizers
with tf.compat.v1.variable_scope("opti",reuse=tf.compat.v1.AUTO_REUSE):
    optimizer = tf.compat.v1.train.AdamOptimizer(float(hyperparameters['learning_rate']), float(hyperparameters['beta1']), float(hyperparameters['beta2']), float(hyperparameters['epsilon'])).minimize(loss)
# Round predictions for MAE calculation
predEr = tf.math.round(pred)
error = tf.compat.v1.metrics.mean_absolute_error(Y, predictions=predEr)
# Out:
# xavier initialized
# 40
# 20
# 10
# (?, ?, ?, 32)
# (?, ?, ?, 32)
# (?, ?, ?, 32)
# (?, ?, ?, 64)
# (?, ?, ?, 64)
# (?, ?, ?, 64)
# (?, ?, ?, 64)
# (?, ?, ?, 128)
# (?, ?, ?, 128)
# (?, ?, ?, 128)
# (?, 128)
# (?, 128)
# (?, 64)
# (?, 64)
# (?, 32)
# (?, 32)
# (?, 16)
# (?, 1)

# %%
batch_size=int(hyperparameters['batch_size'])
epoch= int(hyperparameters['epoch'])
init = tf.compat.v1.global_variables_initializer()
prev_val_err = 0
val_errors = []
firstIter = 1
with tf.compat.v1.Session() as sess:
    print("Session started")
    trainLoss=[]
    valLoss=[]
    valAcc=[]
    sess.run(init)
    sess.run(tf.compat.v1.local_variables_initializer())
    val_X = images_val
    val_Y = labels_val
    for ithepoch in range(int(epoch)):
        tic = time.perf_counter()
        loss_train = None
        for batch in range(len(images)//batch_size):
          batch_x = images[batch*batch_size:min((batch+1)*batch_size,len(images))]    #splits the data to the bacthes for images
          batch_y = labels[batch*batch_size:min((batch+1)*batch_size,len(images))]    #splits the data to the bacthes for labels
          sess.run(optimizer, feed_dict={X: batch_x, Y: batch_y})                     #runs the optimizer which actually makes the training
          loss_train = sess.run(loss, feed_dict={X: batch_x, Y:batch_y})              #runs the loss which already calculated when we run the optimizer and gave us the result
        
        print("Epoch:", '%04d' % (ithepoch+1), "trainLoss=",loss_train)               #shows the result of each epoch
        
        loss_val = sess.run(loss, feed_dict={X:images_val, Y:labels_val})
        err_val = sess.run(error,feed_dict={X:images_val, Y:labels_val})
        '''if hyperparameters['early'] == 1:
          if firstIter == 1 and prev_val_err == 0:
            prev_val_err = err_val
            if firstIter != 1 and prev_val_err != 0:
                difference = err_val - prev_val_err
                val_errors.append(difference)
                prev_val_err = err_val
                if len(val_errors) == 5:
                    if np.amax(val_errors) > 0:
                        break;
                    val_errors.pop(0)
            firstIter == 0
            '''
        valLoss=np.append(valLoss, loss_val)
        valAcc=np.append(valAcc, err_val)
        print("            valLoss=",loss_val, "valAccuracy=",err_val[0])
        toc = time.perf_counter()
        print(f"\trun one epoch is in {toc - tic:0.4f} seconds")
        print()
    loss_test = sess.run(loss, feed_dict={X:images_test, Y:labels_test})
    err_test = sess.run(error,feed_dict={X:images_test, Y:labels_test})
    print()
    print("TEST RESULTS")
    print("Loss for Test Data: " + str(loss_test))
    print("Error for Test Data: " + str(err_test[0]))
# Out:
# Session started
# Epoch: 0001 trainLoss= 1.696513
#             valLoss= 1.6715876 valAccuracy= 0.0
# 	run one epoch is in 8.1760 seconds
#
# Epoch: 0002 trainLoss= 1.701939
#             valLoss= 1.671857 valAccuracy= 1.6199552
# 	run one epoch is in 1.2617 seconds
#
# Epoch: 0003 trainLoss= 1.6933612
#             valLoss= 1.6608795 valAccuracy= 1.5756726
# 	run one epoch is in 1.2624 seconds
#
# Epoch: 0004 trainLoss= 1.6588397
#             valLoss= 1.6251173 valAccuracy= 1.558296
# 	run one epoch is in 1.2567 seconds
#
# Epoch: 0005 trainLoss= 1.6046062
#             valLoss= 1.586374 valAccuracy= 1.5400785
# 	run one epoch is in 1.2580 seconds
#
# Epoch: 0006 trainLoss= 1.5781631
#             valLoss= 1.5900959 valAccuracy= 1.5468609
# 	run one epoch is in 1.2558 seconds
#
# Epoch: 0007 trainLoss= 1.5389076
#             valLoss= 1.5433893 valAccuracy= 1.5440956
# 	run one epoch is in 1.2534 seconds
#
# Epoch: 0008 trainLoss= 1.5150763
#             valLoss= 1.5115088 valAccuracy= 1.5358745
# 	run one epoch is in 1.2585 seconds
#
# Epoch: 0009 trainLoss= 1.5086342
#             valLoss= 1.4997169 valAccuracy= 1.526065
# 	run one epoch is in 1.2598 seconds
#
# Epoch: 0010 trainLoss= 1.4907635
#             valLoss= 1.4883571 valAccuracy= 1.5168161
# 	run one epoch is in 1.2579 seconds
#
# Epoch: 0011 trainLoss= 1.4776351
#             valLoss= 1.4916112 valAccuracy= 1.5080718
# 	run one epoch is in 1.2548 seconds
#
# Epoch: 0012 trainLoss= 1.482204
#             valLoss= 1.4935348 valAccuracy= 1.5001019
# 	run one epoch is in 1.2568 seconds
#
# Epoch: 0013 trainLoss= 1.4745142
#             valLoss= 1.483602 valAccuracy= 1.4940209
# 	run one epoch is in 1.2624 seconds
#
# Epoch: 0014 trainLoss= 1.4466562
#             valLoss= 1.4435273 valAccuracy= 1.4876682
# 	run one epoch is in 1.2572 seconds
#
# Epoch: 0015 trainLoss= 1.4615978
#             valLoss= 1.4430894 valAccuracy= 1.4798206
# 	run one epoch is in 1.2586 seconds
#
# Epoch: 0016 trainLoss= 1.4436718
#             valLoss= 1.4098358 valAccuracy= 1.4735426
# 	run one epoch is in 1.2590 seconds
#
# Epoch: 0017 trainLoss= 1.4287612
#             valLoss= 1.4097677 valAccuracy= 1.4658773
# 	run one epoch is in 1.2574 seconds
#
# Epoch: 0018 trainLoss= 1.5539167
#             valLoss= 1.487242 valAccuracy= 1.4589158
# 	run one epoch is in 1.2627 seconds
#
# Epoch: 0019 trainLoss= 1.4511689
#             valLoss= 1.4021071 valAccuracy= 1.4565895
# 	run one epoch is in 1.2596 seconds
#
# Epoch: 0020 trainLoss= 1.3483061
#             valLoss= 1.3086641 valAccuracy= 1.4503776
# 	run one epoch is in 1.2606 seconds
#
# Epoch: 0021 trainLoss= 1.3532416
#             valLoss= 1.3109602 valAccuracy= 1.4407511
# 	run one epoch is in 1.2539 seconds
#
# Epoch: 0022 trainLoss= 1.2534593
#             valLoss= 1.2605411 valAccuracy= 1.4318813
# 	run one epoch is in 1.2600 seconds
#
# Epoch: 0023 trainLoss= 1.3124129
#             valLoss= 1.2860056 valAccuracy= 1.4206074
# 	run one epoch is in 1.2567 seconds
#
# Epoch: 0024 trainLoss= 1.2738577
#             valLoss= 1.2612818 valAccuracy= 1.4119711
# 	run one epoch is in 1.2570 seconds
#
# Epoch: 0025 trainLoss= 1.2520999
#             valLoss= 1.2399042 valAccuracy= 1.4030737
# 	run one epoch is in 1.2635 seconds
#
# Epoch: 0026 trainLoss= 1.2291852
#             valLoss= 1.2174199 valAccuracy= 1.3938117
# 	run one epoch is in 1.2624 seconds
#
# Epoch: 0027 trainLoss= 1.2155373
#             valLoss= 1.2148764 valAccuracy= 1.3844861
# 	run one epoch is in 1.2642 seconds
#
# Epoch: 0028 trainLoss= 1.1951826
#             valLoss= 1.213937 valAccuracy= 1.3756436
# 	run one epoch is in 1.2591 seconds
#
# Epoch: 0029 trainLoss= 1.208135
#             valLoss= 1.2049669 valAccuracy= 1.3679532
# 	run one epoch is in 1.2598 seconds
#
# Epoch: 0030 trainLoss= 1.1724538
#             valLoss= 1.1897246 valAccuracy= 1.3603294
# 	run one epoch is in 1.2604 seconds
#
# Epoch: 0031 trainLoss= 1.1727364
#             valLoss= 1.2032068 valAccuracy= 1.3523916
# 	run one epoch is in 1.2578 seconds
#
# Epoch: 0032 trainLoss= 1.1557107
#             valLoss= 1.1897416 valAccuracy= 1.3456532
# 	run one epoch is in 1.2561 seconds
#
# Epoch: 0033 trainLoss= 1.1706861
#             valLoss= 1.2075658 valAccuracy= 1.3389854
# 	run one epoch is in 1.2592 seconds
#
# Epoch: 0034 trainLoss= 1.1431403
#             valLoss= 1.1856034 valAccuracy= 1.3329936
# 	run one epoch is in 1.2572 seconds
#
# Epoch: 0035 trainLoss= 1.1273426
#             valLoss= 1.1606168 valAccuracy= 1.3267937
# 	run one epoch is in 1.2645 seconds
#
# Epoch: 0036 trainLoss= 1.190873
#             valLoss= 1.2228949 valAccuracy= 1.3204356
# 	run one epoch is in 1.2580 seconds
#
# Epoch: 0037 trainLoss= 1.1746978
#             valLoss= 1.2071483 valAccuracy= 1.3156763
# 	run one epoch is in 1.2627 seconds
#
# Epoch: 0038 trainLoss= 1.2149376
#             valLoss= 1.2478125 valAccuracy= 1.3105685
# 	run one epoch is in 1.2535 seconds
#
# Epoch: 0039 trainLoss= 1.1831065
#             valLoss= 1.2275548 valAccuracy= 1.3069093
# 	run one epoch is in 1.2578 seconds
#
# Epoch: 0040 trainLoss= 1.2174498
#             valLoss= 1.2558599 valAccuracy= 1.3027194
# 	run one epoch is in 1.2534 seconds
#
# Epoch: 0041 trainLoss= 1.0794377
#             valLoss= 1.1312295 valAccuracy= 1.2998879
# 	run one epoch is in 1.2610 seconds
#
# Epoch: 0042 trainLoss= 1.1200225
#             valLoss= 1.1716785 valAccuracy= 1.2943509
# 	run one epoch is in 1.2598 seconds
#
# Epoch: 0043 trainLoss= 1.1339172
#             valLoss= 1.1853395 valAccuracy= 1.2900652
# 	run one epoch is in 1.2575 seconds
#
# Epoch: 0044 trainLoss= 1.2047672
#             valLoss= 1.2515936 valAccuracy= 1.2861873
# 	run one epoch is in 1.2604 seconds
#
# Epoch: 0045 trainLoss= 1.1122446
#             valLoss= 1.160971 valAccuracy= 1.2838106
# 	run one epoch is in 1.2555 seconds
#
# Epoch: 0046 trainLoss= 1.0353816
#             valLoss= 1.1021292 valAccuracy= 1.2798207
# 	run one epoch is in 1.2540 seconds
#
# Epoch: 0047 trainLoss= 1.1364409
#             valLoss= 1.1923614 valAccuracy= 1.2748586
# 	run one epoch is in 1.2604 seconds
#
# Epoch: 0048 trainLoss= 1.0591189
#             valLoss= 1.1174009 valAccuracy= 1.2715867
# 	run one epoch is in 1.2569 seconds
#
# Epoch: 0049 trainLoss= 1.0206758
#             valLoss= 1.0897125 valAccuracy= 1.2671198
# 	run one epoch is in 1.2588 seconds
#
# Epoch: 0050 trainLoss= 1.1200677
#             valLoss= 1.16995 valAccuracy= 1.2622403
# 	run one epoch is in 1.2547 seconds
#
# Epoch: 0051 trainLoss= 1.0167949
#             valLoss= 1.0868828 valAccuracy= 1.2592825
# 	run one epoch is in 1.2578 seconds
#
# Epoch: 0052 trainLoss= 1.0137167
#             valLoss= 1.0849746 valAccuracy= 1.2545723
# 	run one epoch is in 1.2595 seconds
#
# Epoch: 0053 trainLoss= 1.0477245
#             valLoss= 1.1140665 valAccuracy= 1.2502156
# 	run one epoch is in 1.2676 seconds
#
# Epoch: 0054 trainLoss= 1.072203
#             valLoss= 1.1365477 valAccuracy= 1.246404
# 	run one epoch is in 1.2684 seconds
#
# Epoch: 0055 trainLoss= 0.99205035
#             valLoss= 1.0696026 valAccuracy= 1.2431489
# 	run one epoch is in 1.2717 seconds
#
# Epoch: 0056 trainLoss= 0.9959438
#             valLoss= 1.0771093 valAccuracy= 1.239258
# 	run one epoch is in 1.2729 seconds
#
# Epoch: 0057 trainLoss= 0.9992576
#             valLoss= 1.0778964 valAccuracy= 1.235346
# 	run one epoch is in 1.2578 seconds
#
# Epoch: 0058 trainLoss= 1.0137533
#             valLoss= 1.0969775 valAccuracy= 1.2315907
# 	run one epoch is in 1.2637 seconds
#
# Epoch: 0059 trainLoss= 0.97209096
#             valLoss= 1.0683589 valAccuracy= 1.2282163
# 	run one epoch is in 1.2631 seconds
#
# Epoch: 0060 trainLoss= 0.9571476
#             valLoss= 1.0620561 valAccuracy= 1.2246523
# 	run one epoch is in 1.2642 seconds
#
# Epoch: 0061 trainLoss= 0.9616826
#             valLoss= 1.056163 valAccuracy= 1.221151
# 	run one epoch is in 1.2726 seconds
#
# Epoch: 0062 trainLoss= 0.9501717
#             valLoss= 1.0604458 valAccuracy= 1.2173785
# 	run one epoch is in 1.2709 seconds
#
# Epoch: 0063 trainLoss= 0.95731556
#             valLoss= 1.0649956 valAccuracy= 1.214017
# 	run one epoch is in 1.2737 seconds
#
# Epoch: 0064 trainLoss= 0.9514962
#             valLoss= 1.0624707 valAccuracy= 1.2109402
# 	run one epoch is in 1.2677 seconds
#
# Epoch: 0065 trainLoss= 0.95881844
#             valLoss= 1.065536 valAccuracy= 1.207872
# 	run one epoch is in 1.2667 seconds
#
# Epoch: 0066 trainLoss= 0.9459704
#             valLoss= 1.0457419 valAccuracy= 1.2047603
# 	run one epoch is in 1.2707 seconds
#
# Epoch: 0067 trainLoss= 0.9395529
#             valLoss= 1.0539523 valAccuracy= 1.2016579
# 	run one epoch is in 1.2679 seconds
#
# Epoch: 0068 trainLoss= 0.937932
#             valLoss= 1.04879 valAccuracy= 1.1985978
# 	run one epoch is in 1.2676 seconds
#
# Epoch: 0069 trainLoss= 0.93393403
#             valLoss= 1.0529205 valAccuracy= 1.1957927
# 	run one epoch is in 1.2595 seconds
#
# Epoch: 0070 trainLoss= 0.9310306
#             valLoss= 1.0423979 valAccuracy= 1.1930689
# 	run one epoch is in 1.2584 seconds
#
# Epoch: 0071 trainLoss= 0.93937767
#             valLoss= 1.0651846 valAccuracy= 1.1901985
# 	run one epoch is in 1.2587 seconds
#
# Epoch: 0072 trainLoss= 0.92725706
#             valLoss= 1.0400155 valAccuracy= 1.1877724
# 	run one epoch is in 1.2598 seconds
#
# Epoch: 0073 trainLoss= 0.963696
#             valLoss= 1.0371909 valAccuracy= 1.184853
# 	run one epoch is in 1.2616 seconds
#
# Epoch: 0074 trainLoss= 0.92407525
#             valLoss= 1.0402737 valAccuracy= 1.1821979
# 	run one epoch is in 1.2581 seconds
#
# Epoch: 0075 trainLoss= 1.0579897
#             valLoss= 1.1349753 valAccuracy= 1.1796297
# 	run one epoch is in 1.2621 seconds
#
# Epoch: 0076 trainLoss= 0.9510446
#             valLoss= 1.0319388 valAccuracy= 1.178012
# 	run one epoch is in 1.2596 seconds
#
# Epoch: 0077 trainLoss= 0.9296239
#             valLoss= 1.0269469 valAccuracy= 1.1754926
# 	run one epoch is in 1.2587 seconds
#
# Epoch: 0078 trainLoss= 0.8989582
#             valLoss= 1.039287 valAccuracy= 1.1727623
# 	run one epoch is in 1.2572 seconds
#
# Epoch: 0079 trainLoss= 1.0192585
#             valLoss= 1.1091704 valAccuracy= 1.1703892
# 	run one epoch is in 1.2594 seconds
#
# Epoch: 0080 trainLoss= 1.0587951
#             valLoss= 1.1213986 valAccuracy= 1.1686865
# 	run one epoch is in 1.2612 seconds
#
# Epoch: 0081 trainLoss= 0.9129552
#             valLoss= 1.0190011 valAccuracy= 1.1670684
# 	run one epoch is in 1.2623 seconds
#
# Epoch: 0082 trainLoss= 1.0260726
#             valLoss= 1.104661 valAccuracy= 1.1646044
# 	run one epoch is in 1.2563 seconds
#
# Epoch: 0083 trainLoss= 0.8906207
#             valLoss= 1.0230794 valAccuracy= 1.1628431
# 	run one epoch is in 1.2594 seconds
#
# Epoch: 0084 trainLoss= 0.9058203
#             valLoss= 1.0317291 valAccuracy= 1.1605976
# 	run one epoch is in 1.2666 seconds
#
# Epoch: 0085 trainLoss= 1.0783937
#             valLoss= 1.147144 valAccuracy= 1.1586056
# 	run one epoch is in 1.2565 seconds
#
# Epoch: 0086 trainLoss= 0.9067848
#             valLoss= 1.0400454 valAccuracy= 1.1576102
# 	run one epoch is in 1.2630 seconds
#
# Epoch: 0087 trainLoss= 0.9685709
#             valLoss= 1.07069 valAccuracy= 1.155621
# 	run one epoch is in 1.2644 seconds
#
# Epoch: 0088 trainLoss= 0.8968127
#             valLoss= 1.0190438 valAccuracy= 1.1536518
# 	run one epoch is in 1.2587 seconds
#
# Epoch: 0089 trainLoss= 0.9014654
#             valLoss= 1.046123 valAccuracy= 1.151511
# 	run one epoch is in 1.2572 seconds
#
# Epoch: 0090 trainLoss= 0.89589494
#             valLoss= 1.0245353 valAccuracy= 1.1495944
# 	run one epoch is in 1.2598 seconds
#
# Epoch: 0091 trainLoss= 0.8757454
#             valLoss= 1.0282214 valAccuracy= 1.1474215
# 	run one epoch is in 1.2607 seconds
#
# Epoch: 0092 trainLoss= 0.90719825
#             valLoss= 1.0401031 valAccuracy= 1.1453826
# 	run one epoch is in 1.2583 seconds
#
# Epoch: 0093 trainLoss= 0.8755813
#             valLoss= 1.0271701 valAccuracy= 1.1437293
# 	run one epoch is in 1.2615 seconds
#
# Epoch: 0094 trainLoss= 0.87139696
#             valLoss= 1.0194331 valAccuracy= 1.1418824
# 	run one epoch is in 1.2624 seconds
#
# Epoch: 0095 trainLoss= 0.8976251
#             valLoss= 1.0389506 valAccuracy= 1.1399795
# 	run one epoch is in 1.2573 seconds
#
# Epoch: 0096 trainLoss= 0.9192193
#             valLoss= 1.0528094 valAccuracy= 1.1382582
# 	run one epoch is in 1.2522 seconds
#
# Epoch: 0097 trainLoss= 0.861313
#             valLoss= 1.0172378 valAccuracy= 1.1365612
# 	run one epoch is in 1.2577 seconds
#
# Epoch: 0098 trainLoss= 0.8575351
#             valLoss= 1.0162443 valAccuracy= 1.134691
# 	run one epoch is in 1.2616 seconds
#
# Epoch: 0099 trainLoss= 0.8383367
#             valLoss= 1.0120733 valAccuracy= 1.1328247
# 	run one epoch is in 1.2609 seconds
#
# Epoch: 0100 trainLoss= 0.8381313
#             valLoss= 1.0267199 valAccuracy= 1.1309848
# 	run one epoch is in 1.2598 seconds
#
# Epoch: 0101 trainLoss= 0.85271066
#             valLoss= 1.0237267 valAccuracy= 1.1291816
# 	run one epoch is in 1.2597 seconds
#
# Epoch: 0102 trainLoss= 0.85281247
#             valLoss= 1.0412633 valAccuracy= 1.1275363
# 	run one epoch is in 1.2560 seconds
#
# Epoch: 0103 trainLoss= 0.89525545
#             valLoss= 1.0549649 valAccuracy= 1.1260332
# 	run one epoch is in 1.2572 seconds
#
# Epoch: 0104 trainLoss= 0.8019849
#             valLoss= 1.0121924 valAccuracy= 1.1246136
# 	run one epoch is in 1.2572 seconds
#
# Epoch: 0105 trainLoss= 0.8105085
#             valLoss= 1.0176557 valAccuracy= 1.1229734
# 	run one epoch is in 1.2586 seconds
#
# Epoch: 0106 trainLoss= 0.8025818
#             valLoss= 1.0128151 valAccuracy= 1.1214179
# 	run one epoch is in 1.2580 seconds
#
# Epoch: 0107 trainLoss= 0.8474122
#             valLoss= 1.0290968 valAccuracy= 1.1197648
# 	run one epoch is in 1.2561 seconds
#
# Epoch: 0108 trainLoss= 0.8449742
#             valLoss= 1.0356423 valAccuracy= 1.1183312
# 	run one epoch is in 1.2540 seconds
#
# Epoch: 0109 trainLoss= 0.8266087
#             valLoss= 1.0212955 valAccuracy= 1.116924
# 	run one epoch is in 1.2584 seconds
#
# Epoch: 0110 trainLoss= 0.79112476
#             valLoss= 1.0131428 valAccuracy= 1.1154914
# 	run one epoch is in 1.2584 seconds
#
# Epoch: 0111 trainLoss= 0.79770195
#             valLoss= 1.0253419 valAccuracy= 1.1139625
# 	run one epoch is in 1.2565 seconds
#
# Epoch: 0112 trainLoss= 0.804338
#             valLoss= 1.0170002 valAccuracy= 1.1125116
# 	run one epoch is in 1.2529 seconds
#
# Epoch: 0113 trainLoss= 0.7587884
#             valLoss= 1.0181073 valAccuracy= 1.1110966
# 	run one epoch is in 1.2561 seconds
#
# Epoch: 0114 trainLoss= 0.7412002
#             valLoss= 1.0193825 valAccuracy= 1.1096969
# 	run one epoch is in 1.2562 seconds
#
# Epoch: 0115 trainLoss= 0.82912034
#             valLoss= 1.0386711 valAccuracy= 1.1083707
# 	run one epoch is in 1.2593 seconds
#
# Epoch: 0116 trainLoss= 0.7716145
#             valLoss= 1.0237613 valAccuracy= 1.1072236
# 	run one epoch is in 1.2625 seconds
#
# Epoch: 0117 trainLoss= 0.7514888
#             valLoss= 1.0227374 valAccuracy= 1.1059127
# 	run one epoch is in 1.2589 seconds
#
# Epoch: 0118 trainLoss= 0.7589593
#             valLoss= 1.0357817 valAccuracy= 1.1047008
# 	run one epoch is in 1.2635 seconds
#
# Epoch: 0119 trainLoss= 0.75533736
#             valLoss= 1.0303875 valAccuracy= 1.1035095
# 	run one epoch is in 1.2547 seconds
#
# Epoch: 0120 trainLoss= 0.721009
#             valLoss= 1.0214792 valAccuracy= 1.1024042
# 	run one epoch is in 1.2565 seconds
#
# Epoch: 0121 trainLoss= 0.73970616
#             valLoss= 1.018826 valAccuracy= 1.1010838
# 	run one epoch is in 1.2562 seconds
#
# Epoch: 0122 trainLoss= 0.72772163
#             valLoss= 1.0282197 valAccuracy= 1.099711
# 	run one epoch is in 1.2585 seconds
#
# Epoch: 0123 trainLoss= 0.88256514
#             valLoss= 1.0730217 valAccuracy= 1.0986731
# 	run one epoch is in 1.2584 seconds
#
# Epoch: 0124 trainLoss= 0.7075077
#             valLoss= 1.0160346 valAccuracy= 1.0979528
# 	run one epoch is in 1.2561 seconds
#
# Epoch: 0125 trainLoss= 0.7008687
#             valLoss= 1.0215874 valAccuracy= 1.0966567
# 	run one epoch is in 1.2581 seconds
#
# Epoch: 0126 trainLoss= 0.72379255
#             valLoss= 1.0296558 valAccuracy= 1.0955426
# 	run one epoch is in 1.2564 seconds
#
# Epoch: 0127 trainLoss= 0.73950976
#             valLoss= 1.050842 valAccuracy= 1.0944551
# 	run one epoch is in 1.2619 seconds
#
# Epoch: 0128 trainLoss= 0.6534021
#             valLoss= 1.0258708 valAccuracy= 1.0936496
# 	run one epoch is in 1.2547 seconds
#
# Epoch: 0129 trainLoss= 0.68793523
#             valLoss= 1.0419419 valAccuracy= 1.09255
# 	run one epoch is in 1.2555 seconds
#
# Epoch: 0130 trainLoss= 0.73417944
#             valLoss= 1.0379761 valAccuracy= 1.0917283
# 	run one epoch is in 1.2577 seconds
#
# Epoch: 0131 trainLoss= 0.67392683
#             valLoss= 1.0327861 valAccuracy= 1.0907382
# 	run one epoch is in 1.2581 seconds
#
# Epoch: 0132 trainLoss= 0.7586483
#             valLoss= 1.0433453 valAccuracy= 1.0897802
# 	run one epoch is in 1.2535 seconds
#
# Epoch: 0133 trainLoss= 0.6791117
#             valLoss= 1.036315 valAccuracy= 1.0888792
# 	run one epoch is in 1.2529 seconds
#
# Epoch: 0134 trainLoss= 0.653732
#             valLoss= 1.0317676 valAccuracy= 1.0879328
# 	run one epoch is in 1.2549 seconds
#
# Epoch: 0135 trainLoss= 0.70073473
#             valLoss= 1.0650929 valAccuracy= 1.0870423
# 	run one epoch is in 1.2626 seconds
#
# Epoch: 0136 trainLoss= 0.7090404
#             valLoss= 1.049382 valAccuracy= 1.0864391
# 	run one epoch is in 1.2585 seconds
#
# Epoch: 0137 trainLoss= 0.66299915
#             valLoss= 1.0400829 valAccuracy= 1.0857953
# 	run one epoch is in 1.2615 seconds
#
# Epoch: 0138 trainLoss= 0.70474124
#             valLoss= 1.0627657 valAccuracy= 1.0849072
# 	run one epoch is in 1.2594 seconds
#
# Epoch: 0139 trainLoss= 0.72514457
#             valLoss= 1.0455943 valAccuracy= 1.0843
# 	run one epoch is in 1.2562 seconds
#
# Epoch: 0140 trainLoss= 0.6539026
#             valLoss= 1.0514982 valAccuracy= 1.0834677
# 	run one epoch is in 1.2576 seconds
#
# Epoch: 0141 trainLoss= 0.6321216
#             valLoss= 1.0490501 valAccuracy= 1.0828235
# 	run one epoch is in 1.2565 seconds
#
# Epoch: 0142 trainLoss= 0.6336552
#             valLoss= 1.0627501 valAccuracy= 1.0822043
# 	run one epoch is in 1.2619 seconds
#
# Epoch: 0143 trainLoss= 0.8795802
#             valLoss= 1.1023511 valAccuracy= 1.0815859
# 	run one epoch is in 1.2559 seconds
#
# Epoch: 0144 trainLoss= 0.6237267
#             valLoss= 1.0656583 valAccuracy= 1.0812819
# 	run one epoch is in 1.2555 seconds
#
# Epoch: 0145 trainLoss= 0.7379642
#             valLoss= 1.0662622 valAccuracy= 1.0807097
# 	run one epoch is in 1.2599 seconds
#
# Epoch: 0146 trainLoss= 0.6273933
#             valLoss= 1.0628594 valAccuracy= 1.0801145
# 	run one epoch is in 1.2558 seconds
#
# Epoch: 0147 trainLoss= 0.79067117
#             valLoss= 1.0862391 valAccuracy= 1.0795734
# 	run one epoch is in 1.2546 seconds
#
# Epoch: 0148 trainLoss= 0.5884704
#             valLoss= 1.0639966 valAccuracy= 1.0791694
# 	run one epoch is in 1.2642 seconds
#
# Epoch: 0149 trainLoss= 0.6131448
#             valLoss= 1.0568933 valAccuracy= 1.0786269
# 	run one epoch is in 1.2598 seconds
#
# Epoch: 0150 trainLoss= 0.95700884
#             valLoss= 1.1572326 valAccuracy= 1.0780239
# 	run one epoch is in 1.2602 seconds
#
# Epoch: 0151 trainLoss= 0.5632252
#             valLoss= 1.0704012 valAccuracy= 1.0780194
# 	run one epoch is in 1.2565 seconds
#
# Epoch: 0152 trainLoss= 0.5596785
#             valLoss= 1.0687121 valAccuracy= 1.0775919
# 	run one epoch is in 1.2566 seconds
#
# Epoch: 0153 trainLoss= 0.9425749
#             valLoss= 1.1393342 valAccuracy= 1.077015
# 	run one epoch is in 1.2552 seconds
#
# Epoch: 0154 trainLoss= 0.549008
#             valLoss= 1.0577711 valAccuracy= 1.0768853
# 	run one epoch is in 1.2545 seconds
#
# Epoch: 0155 trainLoss= 0.5744859
#             valLoss= 1.0513932 valAccuracy= 1.0763934
# 	run one epoch is in 1.2605 seconds
#
# Epoch: 0156 trainLoss= 0.6550057
#             valLoss= 1.1198639 valAccuracy= 1.0758426
# 	run one epoch is in 1.2581 seconds
#
# Epoch: 0157 trainLoss= 0.9609182
#             valLoss= 1.1610113 valAccuracy= 1.0756726
# 	run one epoch is in 1.2580 seconds
#
# Epoch: 0158 trainLoss= 0.5693545
#             valLoss= 1.0639445 valAccuracy= 1.0757976
# 	run one epoch is in 1.2567 seconds
#
# Epoch: 0159 trainLoss= 0.5161944
#             valLoss= 1.0686496 valAccuracy= 1.0753108
# 	run one epoch is in 1.2558 seconds
#
# Epoch: 0160 trainLoss= 0.7210678
#             valLoss= 1.0882943 valAccuracy= 1.0748441
# 	run one epoch is in 1.2575 seconds
#
# Epoch: 0161 trainLoss= 0.511532
#             valLoss= 1.0931323 valAccuracy= 1.0745095
# 	run one epoch is in 1.2575 seconds
#
# Epoch: 0162 trainLoss= 0.57604927
#             valLoss= 1.1025785 valAccuracy= 1.074207
# 	run one epoch is in 1.2554 seconds
#
# Epoch: 0163 trainLoss= 0.54917747
#             valLoss= 1.1034018 valAccuracy= 1.0739703
# 	run one epoch is in 1.2612 seconds
#
# Epoch: 0164 trainLoss= 0.6456601
#             valLoss= 1.0704724 valAccuracy= 1.0737435
# 	run one epoch is in 1.2570 seconds
#
# Epoch: 0165 trainLoss= 0.5892834
#             valLoss= 1.1074984 valAccuracy= 1.0732254
# 	run one epoch is in 1.2547 seconds
#
# Epoch: 0166 trainLoss= 0.56147444
#             valLoss= 1.0765666 valAccuracy= 1.0729922
# 	run one epoch is in 1.2641 seconds
#
# Epoch: 0167 trainLoss= 0.4980272
#             valLoss= 1.0796341 valAccuracy= 1.0725795
# 	run one epoch is in 1.2580 seconds
#
# Epoch: 0168 trainLoss= 0.5263933
#             valLoss= 1.0831007 valAccuracy= 1.0721315
# 	run one epoch is in 1.2556 seconds
#
# Epoch: 0169 trainLoss= 0.7136125
#             valLoss= 1.0896066 valAccuracy= 1.0718089
# 	run one epoch is in 1.2582 seconds
#
# Epoch: 0170 trainLoss= 0.5800281
#             valLoss= 1.1163026 valAccuracy= 1.0715233
# 	run one epoch is in 1.2603 seconds
#
# Epoch: 0171 trainLoss= 0.80622387
#             valLoss= 1.1224321 valAccuracy= 1.0713269
# 	run one epoch is in 1.2586 seconds
#
# Epoch: 0172 trainLoss= 0.55363476
#             valLoss= 1.0843736 valAccuracy= 1.0712048
# 	run one epoch is in 1.2590 seconds
#
# Epoch: 0173 trainLoss= 0.48746628
#             valLoss= 1.0954967 valAccuracy= 1.0708885
# 	run one epoch is in 1.2595 seconds
#
# Epoch: 0174 trainLoss= 0.78561693
#             valLoss= 1.1129286 valAccuracy= 1.0705695
# 	run one epoch is in 1.2571 seconds
#
# Epoch: 0175 trainLoss= 0.6046754
#             valLoss= 1.0919123 valAccuracy= 1.0703765
# 	run one epoch is in 1.2552 seconds
#
# Epoch: 0176 trainLoss= 0.6481316
#             valLoss= 1.1472658 valAccuracy= 1.0700257
# 	run one epoch is in 1.2541 seconds
#
# Epoch: 0177 trainLoss= 0.5834129
#             valLoss= 1.0862288 valAccuracy= 1.0700418
# 	run one epoch is in 1.2556 seconds
#
# Epoch: 0178 trainLoss= 0.6182956
#             valLoss= 1.1592505 valAccuracy= 1.0697664
# 	run one epoch is in 1.2598 seconds
#
# Epoch: 0179 trainLoss= 0.5157504
#             valLoss= 1.0819246 valAccuracy= 1.0699854
# 	run one epoch is in 1.2526 seconds
#
# Epoch: 0180 trainLoss= 0.62742263
#             valLoss= 1.1527811 valAccuracy= 1.0697134
# 	run one epoch is in 1.2614 seconds
#
# Epoch: 0181 trainLoss= 0.654561
#             valLoss= 1.0963464 valAccuracy= 1.069787
# 	run one epoch is in 1.2586 seconds
#
# Epoch: 0182 trainLoss= 0.6453186
#             valLoss= 1.0907755 valAccuracy= 1.0696058
# 	run one epoch is in 1.2620 seconds
#
# Epoch: 0183 trainLoss= 0.49937195
#             valLoss= 1.0862153 valAccuracy= 1.0692172
# 	run one epoch is in 1.2626 seconds
#
# Epoch: 0184 trainLoss= 0.46571544
#             valLoss= 1.1056145 valAccuracy= 1.0689186
# 	run one epoch is in 1.2566 seconds
#
# Epoch: 0185 trainLoss= 0.7038075
#             valLoss= 1.1846976 valAccuracy= 1.0687512
# 	run one epoch is in 1.2496 seconds
#
# Epoch: 0186 trainLoss= 0.48608622
#             valLoss= 1.0967287 valAccuracy= 1.0690098
# 	run one epoch is in 1.2496 seconds
#
# Epoch: 0187 trainLoss= 0.77257085
#             valLoss= 1.1351284 valAccuracy= 1.0686508
# 	run one epoch is in 1.2573 seconds
#
# Epoch: 0188 trainLoss= 0.47804487
#             valLoss= 1.097614 valAccuracy= 1.0685894
# 	run one epoch is in 1.2582 seconds
#
# Epoch: 0189 trainLoss= 0.48589548
#             valLoss= 1.1050714 valAccuracy= 1.0683498
# 	run one epoch is in 1.2534 seconds
#
# Epoch: 0190 trainLoss= 0.71833265
#             valLoss= 1.178108 valAccuracy= 1.0681247
# 	run one epoch is in 1.2587 seconds
#
# Epoch: 0191 trainLoss= 0.7844497
#             valLoss= 1.1335335 valAccuracy= 1.0682912
# 	run one epoch is in 1.2539 seconds
#
# Epoch: 0192 trainLoss= 0.71109366
#             valLoss= 1.1179074 valAccuracy= 1.0682155
# 	run one epoch is in 1.2513 seconds
#
# Epoch: 0193 trainLoss= 0.49429765
#             valLoss= 1.0837336 valAccuracy= 1.0681345
# 	run one epoch is in 1.2567 seconds
#
# Epoch: 0194 trainLoss= 0.42644876
#             valLoss= 1.0811487 valAccuracy= 1.0678048
# 	run one epoch is in 1.2556 seconds
#
# Epoch: 0195 trainLoss= 0.5755993
#             valLoss= 1.0993761 valAccuracy= 1.0674379
# 	run one epoch is in 1.2590 seconds
#
# Epoch: 0196 trainLoss= 0.62375134
#             valLoss= 1.1042728 valAccuracy= 1.0672358
# 	run one epoch is in 1.2623 seconds
#
# Epoch: 0197 trainLoss= 0.54305804
#             valLoss= 1.1376472 valAccuracy= 1.0671102
# 	run one epoch is in 1.2583 seconds
#
# Epoch: 0198 trainLoss= 0.45735365
#             valLoss= 1.0903033 valAccuracy= 1.0670881
# 	run one epoch is in 1.2584 seconds
#
# Epoch: 0199 trainLoss= 0.44656372
#             valLoss= 1.0986239 valAccuracy= 1.0668399
# 	run one epoch is in 1.2619 seconds
#
# Epoch: 0200 trainLoss= 0.49427152
#             valLoss= 1.1184425 valAccuracy= 1.0666449
# 	run one epoch is in 1.2610 seconds
#
# Epoch: 0201 trainLoss= 0.63727385
#             valLoss= 1.1130072 valAccuracy= 1.066592
# 	run one epoch is in 1.2578 seconds
#
# Epoch: 0202 trainLoss= 0.4854251
#             valLoss= 1.1409526 valAccuracy= 1.0665451
# 	run one epoch is in 1.2546 seconds
#
# Epoch: 0203 trainLoss= 0.44768268
#             valLoss= 1.1008976 valAccuracy= 1.0664986
# 	run one epoch is in 1.2605 seconds
#
# Epoch: 0204 trainLoss= 0.4011471
#             valLoss= 1.089904 valAccuracy= 1.0663644
# 	run one epoch is in 1.2594 seconds
#
# Epoch: 0205 trainLoss= 0.4757951
#             valLoss= 1.1259978 valAccuracy= 1.0661215
# 	run one epoch is in 1.2561 seconds
#
# Epoch: 0206 trainLoss= 0.5453892
#             valLoss= 1.1034973 valAccuracy= 1.0660888
# 	run one epoch is in 1.2546 seconds
#
# Epoch: 0207 trainLoss= 0.44612038
#             valLoss= 1.1195444 valAccuracy= 1.0659693
# 	run one epoch is in 1.2587 seconds
#
# Epoch: 0208 trainLoss= 0.6173348
#             valLoss= 1.1512206 valAccuracy= 1.0659269
# 	run one epoch is in 1.2570 seconds
#
# Epoch: 0209 trainLoss= 0.5535192
#             valLoss= 1.09779 valAccuracy= 1.0660088
# 	run one epoch is in 1.2604 seconds
#
# Epoch: 0210 trainLoss= 0.6376158
#             valLoss= 1.1517807 valAccuracy= 1.0657787
# 	run one epoch is in 1.2615 seconds
#
# Epoch: 0211 trainLoss= 0.70956856
#             valLoss= 1.1284714 valAccuracy= 1.0659086
# 	run one epoch is in 1.2588 seconds
#
# Epoch: 0212 trainLoss= 0.58000207
#             valLoss= 1.157103 valAccuracy= 1.0658566
# 	run one epoch is in 1.2574 seconds
#
# Epoch: 0213 trainLoss= 0.38682735
#             valLoss= 1.0976079 valAccuracy= 1.0659214
# 	run one epoch is in 1.2557 seconds
#
# Epoch: 0214 trainLoss= 0.39612493
#             valLoss= 1.0935957 valAccuracy= 1.0656645
# 	run one epoch is in 1.2591 seconds
#
# Epoch: 0215 trainLoss= 0.41680837
#             valLoss= 1.1064405 valAccuracy= 1.0654362
# 	run one epoch is in 1.2545 seconds
#
# Epoch: 0216 trainLoss= 0.42057526
#             valLoss= 1.100635 valAccuracy= 1.0653092
# 	run one epoch is in 1.2549 seconds
#
# Epoch: 0217 trainLoss= 0.6661295
#             valLoss= 1.1486646 valAccuracy= 1.0651158
# 	run one epoch is in 1.2550 seconds
#
# Epoch: 0218 trainLoss= 0.40697664
#             valLoss= 1.0927494 valAccuracy= 1.0651774
# 	run one epoch is in 1.2595 seconds
#
# Epoch: 0219 trainLoss= 0.71086055
#             valLoss= 1.1252048 valAccuracy= 1.0649812
# 	run one epoch is in 1.2541 seconds
#
# Epoch: 0220 trainLoss= 0.3952901
#             valLoss= 1.1022491 valAccuracy= 1.0648791
# 	run one epoch is in 1.2543 seconds
#
# Epoch: 0221 trainLoss= 0.5957634
#             valLoss= 1.1129714 valAccuracy= 1.0646912
# 	run one epoch is in 1.2568 seconds
#
# Epoch: 0222 trainLoss= 0.5280217
#             valLoss= 1.098475 valAccuracy= 1.0645202
# 	run one epoch is in 1.2594 seconds
#
# Epoch: 0223 trainLoss= 0.49014583
#             valLoss= 1.1294731 valAccuracy= 1.0643609
# 	run one epoch is in 1.2563 seconds
#
# Epoch: 0224 trainLoss= 0.3601454
#             valLoss= 1.0898091 valAccuracy= 1.0642985
# 	run one epoch is in 1.2592 seconds
#
# Epoch: 0225 trainLoss= 0.4284753
#             valLoss= 1.1163872 valAccuracy= 1.0641016
# 	run one epoch is in 1.2529 seconds
#
# Epoch: 0226 trainLoss= 0.59366053
#             valLoss= 1.1109443 valAccuracy= 1.0640558
# 	run one epoch is in 1.2588 seconds
#
# Epoch: 0227 trainLoss= 0.51726395
#             valLoss= 1.1112759 valAccuracy= 1.0639311
# 	run one epoch is in 1.2537 seconds
#
# Epoch: 0228 trainLoss= 0.5860713
#             valLoss= 1.1235679 valAccuracy= 1.0637976
# 	run one epoch is in 1.2529 seconds
#
# Epoch: 0229 trainLoss= 0.37057132
#             valLoss= 1.0961905 valAccuracy= 1.063744
# 	run one epoch is in 1.2570 seconds
#
# Epoch: 0230 trainLoss= 0.310844
#             valLoss= 1.10058 valAccuracy= 1.0635831
# 	run one epoch is in 1.2650 seconds
#
# Epoch: 0231 trainLoss= 0.3624999
#             valLoss= 1.1016566 valAccuracy= 1.0634236
# 	run one epoch is in 1.2610 seconds
#
# Epoch: 0232 trainLoss= 0.46959662
#             valLoss= 1.1218582 valAccuracy= 1.0632607
# 	run one epoch is in 1.2560 seconds
#
# Epoch: 0233 trainLoss= 0.5369676
#             valLoss= 1.1018971 valAccuracy= 1.0631814
# 	run one epoch is in 1.2582 seconds
#
# Epoch: 0234 trainLoss= 0.49610835
#             valLoss= 1.085226 valAccuracy= 1.063069
# 	run one epoch is in 1.2639 seconds
#
# Epoch: 0235 trainLoss= 0.53272766
#             valLoss= 1.1456517 valAccuracy= 1.0628426
# 	run one epoch is in 1.2541 seconds
#
# Epoch: 0236 trainLoss= 0.5084564
#             valLoss= 1.1492925 valAccuracy= 1.0629377
# 	run one epoch is in 1.2577 seconds
#
# Epoch: 0237 trainLoss= 0.4830747
#             valLoss= 1.1600702 valAccuracy= 1.0630177
# 	run one epoch is in 1.2562 seconds
#
# Epoch: 0238 trainLoss= 0.6491549
#             valLoss= 1.1662135 valAccuracy= 1.063154
# 	run one epoch is in 1.2583 seconds
#
# Epoch: 0239 trainLoss= 0.38225242
#             valLoss= 1.1145741 valAccuracy= 1.0633314
# 	run one epoch is in 1.2573 seconds
#
# Epoch: 0240 trainLoss= 0.4092726
#             valLoss= 1.1023005 valAccuracy= 1.0632681
# 	run one epoch is in 1.2564 seconds
#
# Epoch: 0241 trainLoss= 0.6382551
#             valLoss= 1.1245869 valAccuracy= 1.0631679
# 	run one epoch is in 1.2597 seconds
#
# Epoch: 0242 trainLoss= 0.5820797
#             valLoss= 1.1101832 valAccuracy= 1.0631013
# 	run one epoch is in 1.2586 seconds
#
# Epoch: 0243 trainLoss= 0.39724147
#             valLoss= 1.105349 valAccuracy= 1.0630026
# 	run one epoch is in 1.2523 seconds
#
# Epoch: 0244 trainLoss= 0.32224125
#             valLoss= 1.0995816 valAccuracy= 1.0628587
# 	run one epoch is in 1.2541 seconds
#
# Epoch: 0245 trainLoss= 0.405193
#             valLoss= 1.1013422 valAccuracy= 1.0627297
# 	run one epoch is in 1.2515 seconds
#
# Epoch: 0246 trainLoss= 0.47193533
#             valLoss= 1.1044307 valAccuracy= 1.0625697
# 	run one epoch is in 1.2547 seconds
#
# Epoch: 0247 trainLoss= 0.37362784
#             valLoss= 1.1079087 valAccuracy= 1.062525
# 	run one epoch is in 1.2585 seconds
#
# Epoch: 0248 trainLoss= 0.5568409
#             valLoss= 1.1137168 valAccuracy= 1.0624353
# 	run one epoch is in 1.2535 seconds
#
# Epoch: 0249 trainLoss= 0.51074255
#             valLoss= 1.1456311 valAccuracy= 1.0624006
# 	run one epoch is in 1.2593 seconds
#
# Epoch: 0250 trainLoss= 0.3729961
#             valLoss= 1.1004385 valAccuracy= 1.0624921
# 	run one epoch is in 1.2554 seconds
#
# Epoch: 0251 trainLoss= 0.38732138
#             valLoss= 1.1269561 valAccuracy= 1.0623857
# 	run one epoch is in 1.2585 seconds
#
# Epoch: 0252 trainLoss= 0.38422287
#             valLoss= 1.0956814 valAccuracy= 1.0623962
# 	run one epoch is in 1.2548 seconds
#
# Epoch: 0253 trainLoss= 0.4391477
#             valLoss= 1.1006186 valAccuracy= 1.0622287
# 	run one epoch is in 1.2590 seconds
#
# Epoch: 0254 trainLoss= 0.3741023
#             valLoss= 1.093868 valAccuracy= 1.0621067
# 	run one epoch is in 1.2574 seconds
#
# Epoch: 0255 trainLoss= 0.35455972
#             valLoss= 1.1133312 valAccuracy= 1.0619814
# 	run one epoch is in 1.2528 seconds
#
# Epoch: 0256 trainLoss= 0.42917272
#             valLoss= 1.119443 valAccuracy= 1.061901
# 	run one epoch is in 1.2551 seconds
#
# Epoch: 0257 trainLoss= 0.52990496
#             valLoss= 1.1027322 valAccuracy= 1.0619
# 	run one epoch is in 1.2560 seconds
#
# Epoch: 0258 trainLoss= 0.326238
#             valLoss= 1.1096175 valAccuracy= 1.0617465
# 	run one epoch is in 1.2594 seconds
#
# Epoch: 0259 trainLoss= 0.42180553
#             valLoss= 1.1082493 valAccuracy= 1.0616418
# 	run one epoch is in 1.2550 seconds
#
# Epoch: 0260 trainLoss= 0.42929298
#             valLoss= 1.0930616 valAccuracy= 1.0615553
# 	run one epoch is in 1.2571 seconds
#
# Epoch: 0261 trainLoss= 0.34354413
#             valLoss= 1.1173942 valAccuracy= 1.0614479
# 	run one epoch is in 1.2594 seconds
#
# Epoch: 0262 trainLoss= 0.5596179
#             valLoss= 1.1192881 valAccuracy= 1.0613155
# 	run one epoch is in 1.2582 seconds
#
# Epoch: 0263 trainLoss= 0.35110366
#             valLoss= 1.1238195 valAccuracy= 1.061257
# 	run one epoch is in 1.2561 seconds
#
# Epoch: 0264 trainLoss= 0.36776102
#             valLoss= 1.115143 valAccuracy= 1.0612329
# 	run one epoch is in 1.2616 seconds
#
# Epoch: 0265 trainLoss= 0.32818612
#             valLoss= 1.1021729 valAccuracy= 1.0611539
# 	run one epoch is in 1.2568 seconds
#
# Epoch: 0266 trainLoss= 0.34684312
#             valLoss= 1.1122261 valAccuracy= 1.0610162
# 	run one epoch is in 1.2551 seconds
#
# Epoch: 0267 trainLoss= 0.32810193
#             valLoss= 1.1060477 valAccuracy= 1.0609258
# 	run one epoch is in 1.2491 seconds
#
# Epoch: 0268 trainLoss= 0.3495557
#             valLoss= 1.1062348 valAccuracy= 1.0607859
# 	run one epoch is in 1.2551 seconds
#
# Epoch: 0269 trainLoss= 0.48974186
#             valLoss= 1.1167611 valAccuracy= 1.0606594
# 	run one epoch is in 1.2570 seconds
#
# Epoch: 0270 trainLoss= 0.3969881
#             valLoss= 1.134675 valAccuracy= 1.060584
# 	run one epoch is in 1.2484 seconds
#
# Epoch: 0271 trainLoss= 0.31346914
#             valLoss= 1.1089894 valAccuracy= 1.0606211
# 	run one epoch is in 1.2545 seconds
#
# Epoch: 0272 trainLoss= 0.3756466
#             valLoss= 1.1334498 valAccuracy= 1.0604678
# 	run one epoch is in 1.2571 seconds
#
# Epoch: 0273 trainLoss= 0.43088502
#             valLoss= 1.1422746 valAccuracy= 1.0604557
# 	run one epoch is in 1.2539 seconds
#
# Epoch: 0274 trainLoss= 0.42458653
#             valLoss= 1.1084576 valAccuracy= 1.0604354
# 	run one epoch is in 1.2564 seconds
#
# Epoch: 0275 trainLoss= 0.41817322
#             valLoss= 1.132424 valAccuracy= 1.0603745
# 	run one epoch is in 1.2556 seconds
#
# Epoch: 0276 trainLoss= 0.4665725
#             valLoss= 1.1214297 valAccuracy= 1.0603751
# 	run one epoch is in 1.2537 seconds
#
# Epoch: 0277 trainLoss= 0.5122104
#             valLoss= 1.1329961 valAccuracy= 1.0603797
# 	run one epoch is in 1.2529 seconds
#
# Epoch: 0278 trainLoss= 0.48300105
#             valLoss= 1.1056272 valAccuracy= 1.0603601
# 	run one epoch is in 1.2564 seconds
#
# Epoch: 0279 trainLoss= 0.29768255
#             valLoss= 1.109462 valAccuracy= 1.0602881
# 	run one epoch is in 1.2573 seconds
#
# Epoch: 0280 trainLoss= 0.29546937
#             valLoss= 1.1083266 valAccuracy= 1.0602006
# 	run one epoch is in 1.2597 seconds
#
# Epoch: 0281 trainLoss= 0.4323199
#             valLoss= 1.1026571 valAccuracy= 1.0601097
# 	run one epoch is in 1.2571 seconds
#
# Epoch: 0282 trainLoss= 0.37617317
#             valLoss= 1.1042118 valAccuracy= 1.0600474
# 	run one epoch is in 1.2545 seconds
#
# Epoch: 0283 trainLoss= 0.5469153
#             valLoss= 1.1180624 valAccuracy= 1.0599378
# 	run one epoch is in 1.2610 seconds
#
# Epoch: 0284 trainLoss= 0.53634953
#             valLoss= 1.1578064 valAccuracy= 1.0599043
# 	run one epoch is in 1.2585 seconds
#
# Epoch: 0285 trainLoss= 0.4145685
#             valLoss= 1.1455905 valAccuracy= 1.0600091
# 	run one epoch is in 1.2571 seconds
#
# Epoch: 0286 trainLoss= 0.49775717
#             valLoss= 1.1332741 valAccuracy= 1.06007
# 	run one epoch is in 1.2555 seconds
#
# Epoch: 0287 trainLoss= 0.34252432
#             valLoss= 1.0903016 valAccuracy= 1.0600717
# 	run one epoch is in 1.2642 seconds
#
# Epoch: 0288 trainLoss= 0.33610994
#             valLoss= 1.1032131 valAccuracy= 1.0599405
# 	run one epoch is in 1.2600 seconds
#
# Epoch: 0289 trainLoss= 0.5186738
#             valLoss= 1.1445131 valAccuracy= 1.0598258
# 	run one epoch is in 1.2525 seconds
#
# Epoch: 0290 trainLoss= 0.50377303
#             valLoss= 1.1240503 valAccuracy= 1.059902
# 	run one epoch is in 1.2555 seconds
#
# Epoch: 0291 trainLoss= 0.28827584
#             valLoss= 1.1076835 valAccuracy= 1.059908
# 	run one epoch is in 1.2570 seconds
#
# Epoch: 0292 trainLoss= 0.5042675
#             valLoss= 1.1220005 valAccuracy= 1.0597599
# 	run one epoch is in 1.2581 seconds
#
# Epoch: 0293 trainLoss= 0.43229458
#             valLoss= 1.1388046 valAccuracy= 1.0597204
# 	run one epoch is in 1.2559 seconds
#
# Epoch: 0294 trainLoss= 0.2824249
#             valLoss= 1.0929061 valAccuracy= 1.0597538
# 	run one epoch is in 1.2561 seconds
#
# Epoch: 0295 trainLoss= 0.34151408
#             valLoss= 1.1087314 valAccuracy= 1.059623
# 	run one epoch is in 1.2571 seconds
#
# Epoch: 0296 trainLoss= 0.51589656
#             valLoss= 1.139525 valAccuracy= 1.0595158
# 	run one epoch is in 1.2645 seconds
#
# Epoch: 0297 trainLoss= 0.52941865
#             valLoss= 1.1237887 valAccuracy= 1.0595762
# 	run one epoch is in 1.2683 seconds
#
# Epoch: 0298 trainLoss= 0.5274968
#             valLoss= 1.1096351 valAccuracy= 1.0595492
# 	run one epoch is in 1.2646 seconds
#
# Epoch: 0299 trainLoss= 0.47292167
#             valLoss= 1.1324679 valAccuracy= 1.059481
# 	run one epoch is in 1.2680 seconds
#
# Epoch: 0300 trainLoss= 0.3123065
#             valLoss= 1.093777 valAccuracy= 1.0595033
# 	run one epoch is in 1.2537 seconds
#
# Epoch: 0301 trainLoss= 0.2925651
#             valLoss= 1.1087023 valAccuracy= 1.0593871
# 	run one epoch is in 1.2589 seconds
#
# Epoch: 0302 trainLoss= 0.4921382
#             valLoss= 1.1495324 valAccuracy= 1.059242
# 	run one epoch is in 1.2630 seconds
#
# Epoch: 0303 trainLoss= 0.35376188
#             valLoss= 1.1119574 valAccuracy= 1.059302
# 	run one epoch is in 1.2558 seconds
#
# Epoch: 0304 trainLoss= 0.45506498
#             valLoss= 1.127331 valAccuracy= 1.0591581
# 	run one epoch is in 1.2577 seconds
#
# Epoch: 0305 trainLoss= 0.5053627
#             valLoss= 1.1513599 valAccuracy= 1.0591847
# 	run one epoch is in 1.2553 seconds
#
# Epoch: 0306 trainLoss= 0.31616598
#             valLoss= 1.1037815 valAccuracy= 1.0592296
# 	run one epoch is in 1.2549 seconds
#
# Epoch: 0307 trainLoss= 0.44185454
#             valLoss= 1.1154007 valAccuracy= 1.0590947
# 	run one epoch is in 1.2607 seconds
#
# Epoch: 0308 trainLoss= 0.45306864
#             valLoss= 1.1255914 valAccuracy= 1.0590227
# 	run one epoch is in 1.2733 seconds
#
# Epoch: 0309 trainLoss= 0.3349291
#             valLoss= 1.0927594 valAccuracy= 1.0589802
# 	run one epoch is in 1.2642 seconds
#
# Epoch: 0310 trainLoss= 0.45125282
#             valLoss= 1.1367638 valAccuracy= 1.058822
# 	run one epoch is in 1.2620 seconds
#
# Epoch: 0311 trainLoss= 0.42256618
#             valLoss= 1.1056595 valAccuracy= 1.0587841
# 	run one epoch is in 1.2686 seconds
#
# Epoch: 0312 trainLoss= 0.47223327
#             valLoss= 1.1039355 valAccuracy= 1.0586925
# 	run one epoch is in 1.2652 seconds
#
# Epoch: 0313 trainLoss= 0.4573726
#             valLoss= 1.1061395 valAccuracy= 1.0586301
# 	run one epoch is in 1.2716 seconds
#
# Epoch: 0314 trainLoss= 0.33384028
#             valLoss= 1.0948257 valAccuracy= 1.0585502
# 	run one epoch is in 1.2664 seconds
#
# Epoch: 0315 trainLoss= 0.3129777
#             valLoss= 1.108862 valAccuracy= 1.0583924
# 	run one epoch is in 1.2631 seconds
#
# Epoch: 0316 trainLoss= 0.5154069
#             valLoss= 1.1255902 valAccuracy= 1.0582924
# 	run one epoch is in 1.2539 seconds
#
# Epoch: 0317 trainLoss= 0.33919942
#             valLoss= 1.1153928 valAccuracy= 1.0583066
# 	run one epoch is in 1.2544 seconds
#
# Epoch: 0318 trainLoss= 0.2544206
#             valLoss= 1.1046453 valAccuracy= 1.0582712
# 	run one epoch is in 1.2502 seconds
#
# Epoch: 0319 trainLoss= 0.27874655
#             valLoss= 1.105731 valAccuracy= 1.0581409
# 	run one epoch is in 1.2559 seconds
#
# Epoch: 0320 trainLoss= 0.31699124
#             valLoss= 1.096645 valAccuracy= 1.0580921
# 	run one epoch is in 1.2543 seconds
#
# Epoch: 0321 trainLoss= 0.4758322
#             valLoss= 1.1345154 valAccuracy= 1.0579281
# 	run one epoch is in 1.2562 seconds
#
# Epoch: 0322 trainLoss= 0.4834586
#             valLoss= 1.1466194 valAccuracy= 1.0579398
# 	run one epoch is in 1.2490 seconds
#
# Epoch: 0323 trainLoss= 0.41154647
#             valLoss= 1.0985931 valAccuracy= 1.0580105
# 	run one epoch is in 1.2484 seconds
#
# Epoch: 0324 trainLoss= 0.45189583
#             valLoss= 1.1192629 valAccuracy= 1.0579176
# 	run one epoch is in 1.2473 seconds
#
# Epoch: 0325 trainLoss= 0.28311923
#             valLoss= 1.1109364 valAccuracy= 1.0578704
# 	run one epoch is in 1.2566 seconds
#
# Epoch: 0326 trainLoss= 0.38999927
#             valLoss= 1.1277308 valAccuracy= 1.0577992
# 	run one epoch is in 1.2543 seconds
#
# Epoch: 0327 trainLoss= 0.28967395
#             valLoss= 1.1035942 valAccuracy= 1.0577698
# 	run one epoch is in 1.2584 seconds
#
# Epoch: 0328 trainLoss= 0.29733932
#             valLoss= 1.1061474 valAccuracy= 1.0577062
# 	run one epoch is in 1.2557 seconds
#
# Epoch: 0329 trainLoss= 0.5659995
#             valLoss= 1.1281921 valAccuracy= 1.0575577
# 	run one epoch is in 1.2597 seconds
#
# Epoch: 0330 trainLoss= 0.5558842
#             valLoss= 1.1181492 valAccuracy= 1.0575259
# 	run one epoch is in 1.2567 seconds
#
# Epoch: 0331 trainLoss= 0.4242651
#             valLoss= 1.1380616 valAccuracy= 1.0574739
# 	run one epoch is in 1.2524 seconds
#
# Epoch: 0332 trainLoss= 0.34520707
#             valLoss= 1.1065629 valAccuracy= 1.0574661
# 	run one epoch is in 1.2541 seconds
#
# Epoch: 0333 trainLoss= 0.23572887
#             valLoss= 1.0944625 valAccuracy= 1.0573606
# 	run one epoch is in 1.2551 seconds
#
# Epoch: 0334 trainLoss= 0.31524852
#             valLoss= 1.1088805 valAccuracy= 1.057313
# 	run one epoch is in 1.2557 seconds
#
# Epoch: 0335 trainLoss= 0.31630874
#             valLoss= 1.0862079 valAccuracy= 1.0572084
# 	run one epoch is in 1.2553 seconds
#
# Epoch: 0336 trainLoss= 0.5817728
#             valLoss= 1.11781 valAccuracy= 1.0570076
# 	run one epoch is in 1.2596 seconds
#
# Epoch: 0337 trainLoss= 0.4002537
#             valLoss= 1.1308212 valAccuracy= 1.056948
# 	run one epoch is in 1.2560 seconds
#
# Epoch: 0338 trainLoss= 0.25269428
#             valLoss= 1.0908332 valAccuracy= 1.0569553
# 	run one epoch is in 1.2521 seconds
#
# Epoch: 0339 trainLoss= 0.37401325
#             valLoss= 1.089418 valAccuracy= 1.0568498
# 	run one epoch is in 1.2501 seconds
#
# Epoch: 0340 trainLoss= 0.41602063
#             valLoss= 1.0957488 valAccuracy= 1.0567449
# 	run one epoch is in 1.2543 seconds
#
# Epoch: 0341 trainLoss= 0.30681267
#             valLoss= 1.1162763 valAccuracy= 1.0566934
# 	run one epoch is in 1.2531 seconds
#
# Epoch: 0342 trainLoss= 0.49619406
#             valLoss= 1.1421107 valAccuracy= 1.056639
# 	run one epoch is in 1.2517 seconds
#
# Epoch: 0343 trainLoss= 0.29730162
#             valLoss= 1.0975755 valAccuracy= 1.05668
# 	run one epoch is in 1.2468 seconds
#
# Epoch: 0344 trainLoss= 0.54438186
#             valLoss= 1.1050254 valAccuracy= 1.0565538
# 	run one epoch is in 1.2561 seconds
#
# Epoch: 0345 trainLoss= 0.44860286
#             valLoss= 1.1583451 valAccuracy= 1.0564872
# 	run one epoch is in 1.2577 seconds
#
# Epoch: 0346 trainLoss= 0.28962982
#             valLoss= 1.0938838 valAccuracy= 1.0565997
# 	run one epoch is in 1.2504 seconds
#
# Epoch: 0347 trainLoss= 0.38301426
#             valLoss= 1.0943661 valAccuracy= 1.0564588
# 	run one epoch is in 1.2520 seconds
#
# Epoch: 0348 trainLoss= 0.32831702
#             valLoss= 1.0969052 valAccuracy= 1.0563769
# 	run one epoch is in 1.2519 seconds
#
# Epoch: 0349 trainLoss= 0.24583058
#             valLoss= 1.111318 valAccuracy= 1.0563018
# 	run one epoch is in 1.2502 seconds
#
# Epoch: 0350 trainLoss= 0.39708316
#             valLoss= 1.1189568 valAccuracy= 1.0562369
# 	run one epoch is in 1.2507 seconds
#
# Epoch: 0351 trainLoss= 0.36169124
#             valLoss= 1.1094117 valAccuracy= 1.056198
# 	run one epoch is in 1.2526 seconds
#
# Epoch: 0352 trainLoss= 0.27404597
#             valLoss= 1.0935762 valAccuracy= 1.0561401
# 	run one epoch is in 1.2539 seconds
#
# Epoch: 0353 trainLoss= 0.23830497
#             valLoss= 1.0953841 valAccuracy= 1.056057
# 	run one epoch is in 1.2492 seconds
#
# Epoch: 0354 trainLoss= 0.33932096
#             valLoss= 1.1036664 valAccuracy= 1.0559967
# 	run one epoch is in 1.2468 seconds
#
# Epoch: 0355 trainLoss= 0.27750084
#             valLoss= 1.0995768 valAccuracy= 1.0559303
# 	run one epoch is in 1.2539 seconds
#
# Epoch: 0356 trainLoss= 0.4478127
#             valLoss= 1.1325014 valAccuracy= 1.0558486
# 	run one epoch is in 1.2558 seconds
#
# Epoch: 0357 trainLoss= 0.35704693
#             valLoss= 1.1155834 valAccuracy= 1.0558554
# 	run one epoch is in 1.2522 seconds
#
# Epoch: 0358 trainLoss= 0.3963419
#             valLoss= 1.1343927 valAccuracy= 1.0558151
# 	run one epoch is in 1.2546 seconds
#
# Epoch: 0359 trainLoss= 0.5141002
#             valLoss= 1.1294286 valAccuracy= 1.055797
# 	run one epoch is in 1.2591 seconds
#
# Epoch: 0360 trainLoss= 0.38042396
#             valLoss= 1.0922096 valAccuracy= 1.0558102
# 	run one epoch is in 1.2599 seconds
#
# Epoch: 0361 trainLoss= 0.26088148
#             valLoss= 1.0988702 valAccuracy= 1.0557082
# 	run one epoch is in 1.2596 seconds
#
# Epoch: 0362 trainLoss= 0.4997948
#             valLoss= 1.1167518 valAccuracy= 1.0556377
# 	run one epoch is in 1.2504 seconds
#
# Epoch: 0363 trainLoss= 0.40107012
#             valLoss= 1.0871888 valAccuracy= 1.0555924
# 	run one epoch is in 1.2533 seconds
#
# Epoch: 0364 trainLoss= 0.4467982
#             valLoss= 1.1374127 valAccuracy= 1.0555072
# 	run one epoch is in 1.2546 seconds
#
# Epoch: 0365 trainLoss= 0.48145732
#             valLoss= 1.1191701 valAccuracy= 1.0555795
# 	run one epoch is in 1.2520 seconds
#
# Epoch: 0366 trainLoss= 0.27181312
#             valLoss= 1.11753 valAccuracy= 1.0555778
# 	run one epoch is in 1.2516 seconds
#
# Epoch: 0367 trainLoss= 0.5510376
#             valLoss= 1.1268414 valAccuracy= 1.0555239
# 	run one epoch is in 1.2521 seconds
#
# Epoch: 0368 trainLoss= 0.29837555
#             valLoss= 1.1114627 valAccuracy= 1.05551
# 	run one epoch is in 1.2480 seconds
#
# Epoch: 0369 trainLoss= 0.2840554
#             valLoss= 1.1035357 valAccuracy= 1.0555116
# 	run one epoch is in 1.2514 seconds
#
# Epoch: 0370 trainLoss= 0.35697687
#             valLoss= 1.1087536 valAccuracy= 1.0554036
# 	run one epoch is in 1.2547 seconds
#
# Epoch: 0371 trainLoss= 0.3694616
#             valLoss= 1.1042144 valAccuracy= 1.055357
# 	run one epoch is in 1.2454 seconds
#
# Epoch: 0372 trainLoss= 0.40998858
#             valLoss= 1.1179458 valAccuracy= 1.0553044
# 	run one epoch is in 1.2494 seconds
#
# Epoch: 0373 trainLoss= 0.5085907
#             valLoss= 1.1191807 valAccuracy= 1.0552824
# 	run one epoch is in 1.2477 seconds
#
# Epoch: 0374 trainLoss= 0.31986928
#             valLoss= 1.0939318 valAccuracy= 1.0552603
# 	run one epoch is in 1.2573 seconds
#
# Epoch: 0375 trainLoss= 0.46314597
#             valLoss= 1.1450444 valAccuracy= 1.0551575
# 	run one epoch is in 1.2528 seconds
#
# Epoch: 0376 trainLoss= 0.2621526
#             valLoss= 1.0888981 valAccuracy= 1.0552287
# 	run one epoch is in 1.2553 seconds
#
# Epoch: 0377 trainLoss= 0.34506062
#             valLoss= 1.0848846 valAccuracy= 1.0551146
# 	run one epoch is in 1.2552 seconds
#
# Epoch: 0378 trainLoss= 0.28378367
#             valLoss= 1.1000971 valAccuracy= 1.0549862
# 	run one epoch is in 1.2521 seconds
#
# Epoch: 0379 trainLoss= 0.27343705
#             valLoss= 1.1075091 valAccuracy= 1.0548972
# 	run one epoch is in 1.2522 seconds
#
# Epoch: 0380 trainLoss= 0.31510103
#             valLoss= 1.0923487 valAccuracy= 1.054841
# 	run one epoch is in 1.2532 seconds
#
# Epoch: 0381 trainLoss= 0.44691557
#             valLoss= 1.1357622 valAccuracy= 1.0547203
# 	run one epoch is in 1.2522 seconds
#
# Epoch: 0382 trainLoss= 0.25406688
#             valLoss= 1.0902061 valAccuracy= 1.0547533
# 	run one epoch is in 1.2527 seconds
#
# Epoch: 0383 trainLoss= 0.39845413
#             valLoss= 1.136095 valAccuracy= 1.0546334
# 	run one epoch is in 1.2526 seconds
#
# Epoch: 0384 trainLoss= 0.35144717
#             valLoss= 1.1004273 valAccuracy= 1.0546839
# 	run one epoch is in 1.2539 seconds
#
# Epoch: 0385 trainLoss= 0.42639315
#             valLoss= 1.1322179 valAccuracy= 1.0546029
# 	run one epoch is in 1.2510 seconds
#
# Epoch: 0386 trainLoss= 0.2929913
#             valLoss= 1.1054506 valAccuracy= 1.0546473
# 	run one epoch is in 1.2568 seconds
#
# Epoch: 0387 trainLoss= 0.4084089
#             valLoss= 1.0991108 valAccuracy= 1.0545987
# 	run one epoch is in 1.2548 seconds
#
# Epoch: 0388 trainLoss= 0.29140547
#             valLoss= 1.0934598 valAccuracy= 1.05453
# 	run one epoch is in 1.2520 seconds
#
# Epoch: 0389 trainLoss= 0.52130324
#             valLoss= 1.1226735 valAccuracy= 1.0544156
# 	run one epoch is in 1.2544 seconds
#
# Epoch: 0390 trainLoss= 0.37798646
#             valLoss= 1.1149482 valAccuracy= 1.0544198
# 	run one epoch is in 1.2553 seconds
#
# Epoch: 0391 trainLoss= 0.21130253
#             valLoss= 1.1037835 valAccuracy= 1.0544239
# 	run one epoch is in 1.2538 seconds
#
# Epoch: 0392 trainLoss= 0.4383091
#             valLoss= 1.1348023 valAccuracy= 1.0543622
# 	run one epoch is in 1.2541 seconds
#
# Epoch: 0393 trainLoss= 0.22370712
#             valLoss= 1.0823023 valAccuracy= 1.0544122
# 	run one epoch is in 1.2536 seconds
#
# Epoch: 0394 trainLoss= 0.5127433
#             valLoss= 1.1101508 valAccuracy= 1.0542909
# 	run one epoch is in 1.2517 seconds
#
# Epoch: 0395 trainLoss= 0.28818908
#             valLoss= 1.0933567 valAccuracy= 1.0542356
# 	run one epoch is in 1.2537 seconds
#
# Epoch: 0396 trainLoss= 0.49552843
#             valLoss= 1.1403173 valAccuracy= 1.054121
# 	run one epoch is in 1.2533 seconds
#
# Epoch: 0397 trainLoss= 0.43637106
#             valLoss= 1.1105751 valAccuracy= 1.0541967
# 	run one epoch is in 1.2581 seconds
#
# Epoch: 0398 trainLoss= 0.30397862
#             valLoss= 1.1120883 valAccuracy= 1.0541675
# 	run one epoch is in 1.2518 seconds
#
# Epoch: 0399 trainLoss= 0.31257424
#             valLoss= 1.0842559 valAccuracy= 1.054144
# 	run one epoch is in 1.2503 seconds
#
# Epoch: 0400 trainLoss= 0.41851592
#             valLoss= 1.1008843 valAccuracy= 1.0540308
# 	run one epoch is in 1.2485 seconds
#
# Epoch: 0401 trainLoss= 0.2512247
#             valLoss= 1.0801249 valAccuracy= 1.0540135
# 	run one epoch is in 1.2532 seconds
#
# Epoch: 0402 trainLoss= 0.27543938
#             valLoss= 1.0844312 valAccuracy= 1.0538871
# 	run one epoch is in 1.2564 seconds
#
# Epoch: 0403 trainLoss= 0.18562287
#             valLoss= 1.0980415 valAccuracy= 1.0537419
# 	run one epoch is in 1.2508 seconds
#
# Epoch: 0404 trainLoss= 0.3312447
#             valLoss= 1.1172651 valAccuracy= 1.0536642
# 	run one epoch is in 1.2534 seconds
#
# Epoch: 0405 trainLoss= 0.2579715
#             valLoss= 1.0968815 valAccuracy= 1.0536451
# 	run one epoch is in 1.2510 seconds
#
# Epoch: 0406 trainLoss= 0.40872627
#             valLoss= 1.1062864 valAccuracy= 1.0535542
# 	run one epoch is in 1.2491 seconds
#
# Epoch: 0407 trainLoss= 0.5337512
#             valLoss= 1.1148213 valAccuracy= 1.0534859
# 	run one epoch is in 1.2457 seconds
#
# Epoch: 0408 trainLoss= 0.20884304
#             valLoss= 1.1085663 valAccuracy= 1.0534647
# 	run one epoch is in 1.2508 seconds
#
# Epoch: 0409 trainLoss= 0.2928643
#             valLoss= 1.0990295 valAccuracy= 1.0534133
# 	run one epoch is in 1.2465 seconds
#
# Epoch: 0410 trainLoss= 0.43937415
#             valLoss= 1.1391289 valAccuracy= 1.0533512
# 	run one epoch is in 1.2529 seconds
#
# Epoch: 0411 trainLoss= 0.23609999
#             valLoss= 1.0871744 valAccuracy= 1.0533714
# 	run one epoch is in 1.2504 seconds
#
# Epoch: 0412 trainLoss= 0.45970717
#             valLoss= 1.1123438 valAccuracy= 1.053217
# 	run one epoch is in 1.2533 seconds
#
# Epoch: 0413 trainLoss= 0.4122894
#             valLoss= 1.1308856 valAccuracy= 1.053164
# 	run one epoch is in 1.2615 seconds
#
# Epoch: 0414 trainLoss= 0.39127442
#             valLoss= 1.0974665 valAccuracy= 1.0532118
# 	run one epoch is in 1.2500 seconds
#
# Epoch: 0415 trainLoss= 0.40548563
#             valLoss= 1.1306813 valAccuracy= 1.0531347
# 	run one epoch is in 1.2467 seconds
#
# Epoch: 0416 trainLoss= 0.4946768
#             valLoss= 1.1030802 valAccuracy= 1.0531417
# 	run one epoch is in 1.2490 seconds
#
# Epoch: 0417 trainLoss= 0.4431291
#             valLoss= 1.1405873 valAccuracy= 1.0530868
# 	run one epoch is in 1.2516 seconds
#
# Epoch: 0418 trainLoss= 0.42843732
#             valLoss= 1.1048625 valAccuracy= 1.0531046
# 	run one epoch is in 1.2543 seconds
#
# Epoch: 0419 trainLoss= 0.23001869
#             valLoss= 1.1125195 valAccuracy= 1.0530714
# 	run one epoch is in 1.2492 seconds
#
# Epoch: 0420 trainLoss= 0.46374354
#             valLoss= 1.1282516 valAccuracy= 1.0530678
# 	run one epoch is in 1.2540 seconds
#
# Epoch: 0421 trainLoss= 0.1771728
#             valLoss= 1.0842957 valAccuracy= 1.0531017
# 	run one epoch is in 1.2567 seconds
#
# Epoch: 0422 trainLoss= 0.19935001
#             valLoss= 1.083554 valAccuracy= 1.0530181
# 	run one epoch is in 1.2564 seconds
#
# Epoch: 0423 trainLoss= 0.3154912
#             valLoss= 1.112924 valAccuracy= 1.0529138
# 	run one epoch is in 1.2491 seconds
#
# Epoch: 0424 trainLoss= 0.474326
#             valLoss= 1.1050608 valAccuracy= 1.0528867
# 	run one epoch is in 1.2505 seconds
#
# Epoch: 0425 trainLoss= 0.18857369
#             valLoss= 1.0889244 valAccuracy= 1.0528281
# 	run one epoch is in 1.2469 seconds
#
# Epoch: 0426 trainLoss= 0.23220411
#             valLoss= 1.0781969 valAccuracy= 1.0527328
# 	run one epoch is in 1.2515 seconds
#
# Epoch: 0427 trainLoss= 0.18980728
#             valLoss= 1.0941452 valAccuracy= 1.0526327
# 	run one epoch is in 1.2553 seconds
#
# Epoch: 0428 trainLoss= 0.27148637
#             valLoss= 1.10109 valAccuracy= 1.0525488
# 	run one epoch is in 1.2460 seconds
#
# Epoch: 0429 trainLoss= 0.29073006
#             valLoss= 1.0813153 valAccuracy= 1.0524942
# 	run one epoch is in 1.2559 seconds
#
# Epoch: 0430 trainLoss= 0.2681666
#             valLoss= 1.0866437 valAccuracy= 1.0523927
# 	run one epoch is in 1.2511 seconds
#
# Epoch: 0431 trainLoss= 0.27547598
#             valLoss= 1.102474 valAccuracy= 1.0523074
# 	run one epoch is in 1.2542 seconds
#
# Epoch: 0432 trainLoss= 0.3978299
#             valLoss= 1.08868 valAccuracy= 1.0522327
# 	run one epoch is in 1.2529 seconds
#
# Epoch: 0433 trainLoss= 0.15780227
#             valLoss= 1.0800157 valAccuracy= 1.0521092
# 	run one epoch is in 1.2514 seconds
#
# Epoch: 0434 trainLoss= 0.22521782
#             valLoss= 1.0815687 valAccuracy= 1.0519967
# 	run one epoch is in 1.2478 seconds
#
# Epoch: 0435 trainLoss= 0.3712837
#             valLoss= 1.1203734 valAccuracy= 1.0518975
# 	run one epoch is in 1.2502 seconds
#
# Epoch: 0436 trainLoss= 0.21915893
#             valLoss= 1.0963837 valAccuracy= 1.0518994
# 	run one epoch is in 1.2545 seconds
#
# Epoch: 0437 trainLoss= 0.29554135
#             valLoss= 1.0874947 valAccuracy= 1.0518292
# 	run one epoch is in 1.2506 seconds
#
# Epoch: 0438 trainLoss= 0.2688522
#             valLoss= 1.0791779 valAccuracy= 1.0517516
# 	run one epoch is in 1.2566 seconds
#
# Epoch: 0439 trainLoss= 0.28098822
#             valLoss= 1.1002927 valAccuracy= 1.0516565
# 	run one epoch is in 1.2489 seconds
#
# Epoch: 0440 trainLoss= 0.45610347
#             valLoss= 1.1125829 valAccuracy= 1.0516052
# 	run one epoch is in 1.2534 seconds
#
# Epoch: 0441 trainLoss= 0.44124588
#             valLoss= 1.0881525 valAccuracy= 1.0516205
# 	run one epoch is in 1.2508 seconds
#
# Epoch: 0442 trainLoss= 0.24898645
#             valLoss= 1.0884694 valAccuracy= 1.0515898
# 	run one epoch is in 1.2549 seconds
#
# Epoch: 0443 trainLoss= 0.22226354
#             valLoss= 1.0898197 valAccuracy= 1.0515112
# 	run one epoch is in 1.2516 seconds
#
# Epoch: 0444 trainLoss= 0.2076026
#             valLoss= 1.078558 valAccuracy= 1.0514354
# 	run one epoch is in 1.2614 seconds
#
# Epoch: 0445 trainLoss= 0.22573802
#             valLoss= 1.0980028 valAccuracy= 1.0512968
# 	run one epoch is in 1.2569 seconds
#
# Epoch: 0446 trainLoss= 0.38275504
#             valLoss= 1.1395246 valAccuracy= 1.0512698
# 	run one epoch is in 1.2529 seconds
#
# Epoch: 0447 trainLoss= 0.25791693
#             valLoss= 1.0917957 valAccuracy= 1.0513182
# 	run one epoch is in 1.2552 seconds
#
# Epoch: 0448 trainLoss= 0.34568036
#             valLoss= 1.0885262 valAccuracy= 1.0512384
# 	run one epoch is in 1.2581 seconds
#
# Epoch: 0449 trainLoss= 0.17670357
#             valLoss= 1.0921375 valAccuracy= 1.0511416
# 	run one epoch is in 1.2551 seconds
#
# Epoch: 0450 trainLoss= 0.2152547
#             valLoss= 1.0902874 valAccuracy= 1.0510577
# 	run one epoch is in 1.2505 seconds
#
# Epoch: 0451 trainLoss= 0.29980153
#             valLoss= 1.1062585 valAccuracy= 1.050979
# 	run one epoch is in 1.2489 seconds
#
# Epoch: 0452 trainLoss= 0.43925962
#             valLoss= 1.0930771 valAccuracy= 1.0509356
# 	run one epoch is in 1.2519 seconds
#
# Epoch: 0453 trainLoss= 0.2069564
#             valLoss= 1.0894945 valAccuracy= 1.0508602
# 	run one epoch is in 1.2525 seconds
#
# Epoch: 0454 trainLoss= 0.20640239
#             valLoss= 1.0883323 valAccuracy= 1.05079
# 	run one epoch is in 1.2482 seconds
#
# Epoch: 0455 trainLoss= 0.35800815
#             valLoss= 1.0922734 valAccuracy= 1.0507151
# 	run one epoch is in 1.2569 seconds
#
# Epoch: 0456 trainLoss= 0.38847676
#             valLoss= 1.1187725 valAccuracy= 1.0506678
# 	run one epoch is in 1.2482 seconds
#
# Epoch: 0457 trainLoss= 0.20066635
#             valLoss= 1.0808696 valAccuracy= 1.0506402
# 	run one epoch is in 1.2562 seconds
#
# Epoch: 0458 trainLoss= 0.16521035
#             valLoss= 1.0800823 valAccuracy= 1.0505441
# 	run one epoch is in 1.2552 seconds
#
# Epoch: 0459 trainLoss= 0.27599174
#             valLoss= 1.0857375 valAccuracy= 1.0504264
# 	run one epoch is in 1.2495 seconds
#
# Epoch: 0460 trainLoss= 0.27992928
#             valLoss= 1.0838844 valAccuracy= 1.0503287
# 	run one epoch is in 1.2532 seconds
#
# Epoch: 0461 trainLoss= 0.19385093
#             valLoss= 1.0690705 valAccuracy= 1.0502291
# 	run one epoch is in 1.2548 seconds
#
# Epoch: 0462 trainLoss= 0.29627344
#             valLoss= 1.0725796 valAccuracy= 1.0501056
# 	run one epoch is in 1.2482 seconds
#
# Epoch: 0463 trainLoss= 0.2685027
#             valLoss= 1.0942861 valAccuracy= 1.0500287
# 	run one epoch is in 1.2490 seconds
#
# Epoch: 0464 trainLoss= 0.22604957
#             valLoss= 1.0815183 valAccuracy= 1.0499787
# 	run one epoch is in 1.2501 seconds
#
# Epoch: 0465 trainLoss= 0.30089006
#             valLoss= 1.1185284 valAccuracy= 1.0498759
# 	run one epoch is in 1.2503 seconds
#
# Epoch: 0466 trainLoss= 0.34079182
#             valLoss= 1.0943472 valAccuracy= 1.0498409
# 	run one epoch is in 1.2544 seconds
#
# Epoch: 0467 trainLoss= 0.5020275
#             valLoss= 1.1071815 valAccuracy= 1.0497797
# 	run one epoch is in 1.2512 seconds
#
# Epoch: 0468 trainLoss= 0.17845023
#             valLoss= 1.0885566 valAccuracy= 1.0497451
# 	run one epoch is in 1.2584 seconds
#
# Epoch: 0469 trainLoss= 0.55392116
#             valLoss= 1.177568 valAccuracy= 1.0496722
# 	run one epoch is in 1.2578 seconds
#
# Epoch: 0470 trainLoss= 0.33914232
#             valLoss= 1.1041881 valAccuracy= 1.0497792
# 	run one epoch is in 1.2489 seconds
#
# Epoch: 0471 trainLoss= 0.2762592
#             valLoss= 1.0920941 valAccuracy= 1.0497304
# 	run one epoch is in 1.2491 seconds
#
# Epoch: 0472 trainLoss= 0.30236325
#             valLoss= 1.0773361 valAccuracy= 1.0496701
# 	run one epoch is in 1.2534 seconds
#
# Epoch: 0473 trainLoss= 0.28739747
#             valLoss= 1.0846417 valAccuracy= 1.0495577
# 	run one epoch is in 1.2534 seconds
#
# Epoch: 0474 trainLoss= 0.275174
#             valLoss= 1.0993257 valAccuracy= 1.0494838
# 	run one epoch is in 1.2502 seconds
#
# Epoch: 0475 trainLoss= 0.30819654
#             valLoss= 1.0827132 valAccuracy= 1.0494622
# 	run one epoch is in 1.2521 seconds
#
# Epoch: 0476 trainLoss= 0.47907105
#             valLoss= 1.1106266 valAccuracy= 1.0493722
# 	run one epoch is in 1.2529 seconds
#
# Epoch: 0477 trainLoss= 0.31499094
#             valLoss= 1.0775728 valAccuracy= 1.0493509
# 	run one epoch is in 1.2493 seconds
#
# Epoch: 0478 trainLoss= 0.20027363
#             valLoss= 1.0868834 valAccuracy= 1.0492239
# 	run one epoch is in 1.2563 seconds
#
# Epoch: 0479 trainLoss= 0.42318854
#             valLoss= 1.0882034 valAccuracy= 1.0491444
# 	run one epoch is in 1.2480 seconds
#
# Epoch: 0480 trainLoss= 0.41026694
#             valLoss= 1.1381091 valAccuracy= 1.0490745
# 	run one epoch is in 1.2478 seconds
#
# Epoch: 0481 trainLoss= 0.17464668
#             valLoss= 1.0842648 valAccuracy= 1.0491078
# 	run one epoch is in 1.2545 seconds
#
# Epoch: 0482 trainLoss= 0.21353635
#             valLoss= 1.1045415 valAccuracy= 1.0490546
# 	run one epoch is in 1.2466 seconds
#
# Epoch: 0483 trainLoss= 0.21505246
#             valLoss= 1.1024729 valAccuracy= 1.049018
# 	run one epoch is in 1.2492 seconds
#
# Epoch: 0484 trainLoss= 0.3407879
#             valLoss= 1.082351 valAccuracy= 1.0489514
# 	run one epoch is in 1.2466 seconds
#
# Epoch: 0485 trainLoss= 0.2885343
#             valLoss= 1.1080599 valAccuracy= 1.0488733
# 	run one epoch is in 1.2566 seconds
#
# Epoch: 0486 trainLoss= 0.27649927
#             valLoss= 1.0984925 valAccuracy= 1.0488535
# 	run one epoch is in 1.2507 seconds
#
# Epoch: 0487 trainLoss= 0.19733891
#             valLoss= 1.0948856 valAccuracy= 1.0487876
# 	run one epoch is in 1.2507 seconds
#
# Epoch: 0488 trainLoss= 0.34042448
#             valLoss= 1.0835732 valAccuracy= 1.0487311
# 	run one epoch is in 1.2526 seconds
#
# Epoch: 0489 trainLoss= 0.45653105
#             valLoss= 1.0825578 valAccuracy= 1.0486841
# 	run one epoch is in 1.2557 seconds
#
# Epoch: 0490 trainLoss= 0.43789554
#             valLoss= 1.0936162 valAccuracy= 1.0486189
# 	run one epoch is in 1.2482 seconds
#
# Epoch: 0491 trainLoss= 0.3584329
#             valLoss= 1.1364568 valAccuracy= 1.0485723
# 	run one epoch is in 1.2490 seconds
#
# Epoch: 0492 trainLoss= 0.20920782
#             valLoss= 1.0847977 valAccuracy= 1.0485442
# 	run one epoch is in 1.2550 seconds
#
# Epoch: 0493 trainLoss= 0.18726316
#             valLoss= 1.0847099 valAccuracy= 1.0484729
# 	run one epoch is in 1.2547 seconds
#
# Epoch: 0494 trainLoss= 0.39574888
#             valLoss= 1.1286916 valAccuracy= 1.0484041
# 	run one epoch is in 1.2545 seconds
#
# Epoch: 0495 trainLoss= 0.40683788
#             valLoss= 1.0883392 valAccuracy= 1.0484151
# 	run one epoch is in 1.2516 seconds
#
# Epoch: 0496 trainLoss= 0.35803667
#             valLoss= 1.1171417 valAccuracy= 1.048358
# 	run one epoch is in 1.2492 seconds
#
# Epoch: 0497 trainLoss= 0.16463467
#             valLoss= 1.0828341 valAccuracy= 1.0483441
# 	run one epoch is in 1.2566 seconds
#
# Epoch: 0498 trainLoss= 0.17169353
#             valLoss= 1.0805316 valAccuracy= 1.0482671
# 	run one epoch is in 1.2512 seconds
#
# Epoch: 0499 trainLoss= 0.22744566
#             valLoss= 1.0953273 valAccuracy= 1.0482085
# 	run one epoch is in 1.2499 seconds
#
# Epoch: 0500 trainLoss= 0.3365311
#             valLoss= 1.1033319 valAccuracy= 1.0481658
# 	run one epoch is in 1.2476 seconds
#
#
# TEST RESULTS
# Loss for Test Data: 1.1447963
# Error for Test Data: 1.0481368
